# %% [markdown]
# This notebook shows how to use LLMs in combination with Neo4j(https://neo4j.com/), a graph database, to perform Retrieval Augmented Generation (RAG).
#
# Why use RAG?
#
# If you want to use LLMs to generate answers based on your own content or knowledge base, instead of providing large context when prompting the model, you can fetch the relevant information in a database and use this information to generate a response.
#
# This allows you to:
#
# 1. Reduce hallucinations
# 2. Provide relevant, up to date information to your users
# 3. Leverage your own content/knowledge base
#
# Why use a graph database?
#
# If you have data where relationships between data points are important and you might want to leverage that, then it might be worth considering graph databases instead of traditional relational databases.
#
# Graph databases are good to address the following:
#
# 1. Navigating deep hierarchies
# 2. Finding hidden connections between items
# 3. Discovering relationships between items
#
# Use cases
#
# Graph databases are particularly relevant for recommendation systems, network relationships or analysing correlation between data points.
#
# Example use cases for RAG with graph databases include:
#
# 1. Recommendation chatbot
# 2. AI-augmented CRM
# 3. Tool to analyse customer behavior with natural language
#
# Depending on your use case, you can assess whether using a graph database makes sense.
#
# In this notebook, we will build a product recommendation chatbot, with a graph database that contains Amazon products data.

# %% [markdown]
# We will start by installing and importing the relevant libraries.
#
# Make sure you have your OpenAI account set up and you have your OpenAI API key handy.

# %%
# Optional: run to install the libraries locally if you haven't already 
# !pip3 install langchain
# !pip3 install openai
# !pip3 install neo4j
# Out:
# Collecting langchain
#   Downloading langchain-1.0.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain)
#   Using cached langchain_core-1.0.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langgraph<1.1.0,>=1.0.0 (from langchain)
#   Downloading langgraph-1.0.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain) (2.11.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (0.4.29)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (2.1.2)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.0 (from langgraph<1.1.0,>=1.0.0->langchain)
#   Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langgraph<1.1.0,>=1.0.0->langchain) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (4.9.0)
# Requirement already satisfied: certifi in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (1.0.8)
# Requirement already satisfied: idna in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.0->langchain) (1.3.1)
# Downloading langchain-1.0.2-py3-none-any.whl (107 kB)
# Using cached langchain_core-1.0.0-py3-none-any.whl (467 kB)
# Downloading langgraph-1.0.1-py3-none-any.whl (155 kB)
# Downloading langgraph_prebuilt-1.0.1-py3-none-any.whl (28 kB)
# Installing collected packages: langchain-core, langgraph-prebuilt, langgraph, langchain
#
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------------------------------------- 0/4 [langchain-core]
#   Attempting uninstall: langgraph-prebuilt
#    ---------------------------------------- 0/4 [langchain-core]
#     Found existing installation: langgraph-prebuilt 0.7.0rc1
#    ---------------------------------------- 0/4 [langchain-core]
#     Uninstalling langgraph-prebuilt-0.7.0rc1:
#    ---------------------------------------- 0/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langgraph-prebuilt]
#       Successfully uninstalled langgraph-prebuilt-0.7.0rc1
#    ---------- ----------------------------- 1/4 [langgraph-prebuilt]
#    -------------------- ------------------- 2/4 [langgraph]
#    -------------------- ------------------- 2/4 [langgraph]
#    -------------------- ------------------- 2/4 [langgraph]
#    -------------------- ------------------- 2/4 [langgraph]
#    -------------------- ------------------- 2/4 [langgraph]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ---------------------------------------- 4/4 [langchain]
#
# Successfully installed langchain-1.0.2 langchain-core-1.0.0 langgraph-1.0.1 langgraph-prebuilt-1.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-anthropic 0.3.20 requires langchain-core<1.0.0,>=0.3.76, but you have langchain-core 1.0.0 which is incompatible.
# langchain-ollama 0.3.8 requires langchain-core<1.0.0,>=0.3.76, but you have langchain-core 1.0.0 which is incompatible.
# langchain-openai 0.3.33 requires langchain-core<1.0.0,>=0.3.76, but you have langchain-core 1.0.0 which is incompatible.
# Requirement already satisfied: openai in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (1.108.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from openai) (2.11.3)
# Requirement already satisfied: sniffio in c:\users\sushi\appdata\roaming\python\python311\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->openai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: colorama in c:\users\sushi\appdata\roaming\python\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Collecting neo4j
#   Using cached neo4j-6.0.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pytz in c:\users\sushi\appdata\roaming\python\python311\site-packages (from neo4j) (2023.3)
# Using cached neo4j-6.0.2-py3-none-any.whl (325 kB)
# Installing collected packages: neo4j
# Successfully installed neo4j-6.0.2

# %%
import os
import json 
import pandas as pd

# %%
# Optional: run to load environment variables from a .env file.
# This is not required if you have exported your env variables in another way or if you set it manually
# !pip3 install python-dotenv
from dotenv import load_dotenv
load_dotenv()

# Set the OpenAI API key env variable manually
# os.environ["OPENAI_API_KEY"] = "<your_api_key>"

print(os.environ["OPENAI_API_KEY"])
# Out:
# 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

# %% [markdown]
# Dataset
#
# We will use a dataset that was created from a relational database and converted to a json format, creating relationships between entities with the completions API.
#
# We will then load this data into the graph db to be able to query it.

# %%
# Loading a json dataset from a file
file_path = 'data/amazon_product_kg.json'

with open(file_path, 'r') as file:
    jsonData = json.load(file)

# %%
df =  pd.read_json(file_path)
df.head()
# Out:
#    product_id           product       relationship     entity_type  \
# 0     1925202  Blackout Curtain        hasCategory        category
# 1     1925202  Blackout Curtain           hasBrand           brand
# 2     1925202  Blackout Curtain  hasCharacteristic  characteristic
# 3     1925202  Blackout Curtain  hasCharacteristic  characteristic
# 4     1925202  Blackout Curtain  hasCharacteristic  characteristic
#
#       entity_value  PRODUCT_ID  \
# 0  home decoration     1925202
# 1        ArtzFolio     1925202
# 2          Eyelets     1925202
# 3         Tie Back     1925202
# 4      100% opaque     1925202
#
#                                                TITLE  \
# 0  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 2  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 3  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 4  ArtzFolio Tulip Flowers Blackout Curtain for D...
#
#                                        BULLET_POINTS DESCRIPTION  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...        None
# 1  [LUXURIOUS & APPEALING: Beautiful custom-made ...        None
# 2  [LUXURIOUS & APPEALING: Beautiful custom-made ...        None
# 3  [LUXURIOUS & APPEALING: Beautiful custom-made ...        None
# 4  [LUXURIOUS & APPEALING: Beautiful custom-made ...        None
#
#    PRODUCT_TYPE_ID  PRODUCT_LENGTH
# 0             1650         2125.98
# 1             1650         2125.98
# 2             1650         2125.98
# 3             1650         2125.98
# 4             1650         2125.98

# %%
import dotenv
import os
from neo4j import GraphDatabase

# load_status = dotenv.load_dotenv("Neo4j-56755c78-Created-2025-10-23.txt")
# if load_status is False:
#     raise RuntimeError('Environment variables not loaded.')

URI = os.getenv("NEO4J_URI")
AUTH = (os.getenv("NEO4J_USERNAME"), os.getenv("NEO4J_PASSWORD"))

with GraphDatabase.driver(URI, auth=AUTH) as driver:
    driver.verify_connectivity()
    print("Connection established.")
# Out:
# Connection established.

# %% [markdown]
# We will use langchain_neo4j package to connect to neo4j DB instead of the above neo4j package

# %%
# DB credentials
url = os.getenv("NEO4J_URI")
username =os.getenv("NEO4J_USERNAME")
password = os.getenv("NEO4J_PASSWORD")

# %%
# !pip3 install langchain_neo4j # if not already installed
# Out:
# Collecting langchain_neo4j
#   Downloading langchain_neo4j-0.5.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting langchain<0.4.0,>=0.3.7 (from langchain_neo4j)
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<0.4.0,>=0.3.39 (from langchain_neo4j)
#   Using cached langchain_core-0.3.79-py3-none-any.whl.metadata (3.2 kB)
# Collecting neo4j<6.0.0,>=5.25.0 (from langchain_neo4j)
#   Downloading neo4j-5.28.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting neo4j-graphrag<2.0.0,>=1.9.0 (from langchain_neo4j)
#   Downloading neo4j_graphrag-1.10.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.4.29)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.0.23)
# Requirement already satisfied: requests<3,>=2 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (3.10.16)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (4.9.0)
# Requirement already satisfied: certifi in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (1.0.8)
# Requirement already satisfied: idna in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.14.0)
# Requirement already satisfied: pytz in c:\users\sushi\appdata\roaming\python\python311\site-packages (from neo4j<6.0.0,>=5.25.0->langchain_neo4j) (2023.3)
# Collecting fsspec<2025.0.0,>=2024.9.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair<0.45.0,>=0.44.1 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Collecting numpy<3.0.0,>=2.0.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading numpy-2.3.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting pypdf<7.0.0,>=6.0.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading pypdf-6.1.3-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.13.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j) (1.13.1)
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.20240917 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain_neo4j) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.5.0)
# Collecting numpy<3.0.0,>=2.0.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from SQLAlchemy<3,>=1.4->langchain<0.4.0,>=0.3.7->langchain_neo4j) (3.2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (1.3.1)
# Downloading langchain_neo4j-0.5.0-py3-none-any.whl (31 kB)
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-0.3.79-py3-none-any.whl (449 kB)
# Downloading neo4j-5.28.2-py3-none-any.whl (313 kB)
# Downloading neo4j_graphrag-1.10.0-py3-none-any.whl (201 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading json_repair-0.44.1-py3-none-any.whl (22 kB)
# Downloading pypdf-6.1.3-py3-none-any.whl (323 kB)
# Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.9 MB 9.3 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.9 MB 8.8 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.9 MB 7.9 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.9 MB 8.0 MB/s eta 0:00:01
#    ------------------------- -------------- 8.4/12.9 MB 8.3 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.9 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.9 MB 8.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 6.9 MB/s  0:00:01
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Installing collected packages: types-pyyaml, pypdf, numpy, neo4j, json-repair, fsspec, neo4j-graphrag, langchain-core, langchain, langchain_neo4j
#
#    ---- -----------------------------------  1/10 [pypdf]
#    ---- -----------------------------------  1/10 [pypdf]
#    ---- -----------------------------------  1/10 [pypdf]
#    ---- -----------------------------------  1/10 [pypdf]
#    ---- -----------------------------------  1/10 [pypdf]
#   Attempting uninstall: numpy
#    ---- -----------------------------------  1/10 [pypdf]
#     Found existing installation: numpy 1.26.2
#    ---- -----------------------------------  1/10 [pypdf]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#     Uninstalling numpy-1.26.2:
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#       Successfully uninstalled numpy-1.26.2
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#    -------- -------------------------------  2/10 [numpy]
#   Attempting uninstall: neo4j
#    -------- -------------------------------  2/10 [numpy]
#    ------------ ---------------------------  3/10 [neo4j]
#     Found existing installation: neo4j 6.0.2
#    ------------ ---------------------------  3/10 [neo4j]
#     Uninstalling neo4j-6.0.2:
#    ------------ ---------------------------  3/10 [neo4j]
#       Successfully uninstalled neo4j-6.0.2
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#    ------------ ---------------------------  3/10 [neo4j]
#   Attempting uninstall: fsspec
#    ------------ ---------------------------  3/10 [neo4j]
#     Found existing installation: fsspec 2025.3.0
#    ------------ ---------------------------  3/10 [neo4j]
#     Uninstalling fsspec-2025.3.0:
#    ------------ ---------------------------  3/10 [neo4j]
#    -------------------- -------------------  5/10 [fsspec]
#       Successfully uninstalled fsspec-2025.3.0
#    -------------------- -------------------  5/10 [fsspec]
#    -------------------- -------------------  5/10 [fsspec]
#    -------------------- -------------------  5/10 [fsspec]
#    -------------------- -------------------  5/10 [fsspec]
#    -------------------- -------------------  5/10 [fsspec]
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#   Attempting uninstall: langchain-core
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#     Found existing installation: langchain-core 1.0.0
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#     Uninstalling langchain-core-1.0.0:
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#       Successfully uninstalled langchain-core-1.0.0
#    ------------------------ ---------------  6/10 [neo4j-graphrag]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#    ---------------------------- -----------  7/10 [langchain-core]
#   Attempting uninstall: langchain
#    ---------------------------- -----------  7/10 [langchain-core]
#     Found existing installation: langchain 1.0.2
#    ---------------------------- -----------  7/10 [langchain-core]
#     Uninstalling langchain-1.0.2:
#    ---------------------------- -----------  7/10 [langchain-core]
#       Successfully uninstalled langchain-1.0.2
#    ---------------------------- -----------  7/10 [langchain-core]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    -------------------------------- -------  8/10 [langchain]
#    ------------------------------------ ---  9/10 [langchain_neo4j]
#    ---------------------------------------- 10/10 [langchain_neo4j]
#
# Successfully installed fsspec-2024.12.0 json-repair-0.44.1 langchain-0.3.27 langchain-core-0.3.79 langchain_neo4j-0.5.0 neo4j-5.28.2 neo4j-graphrag-1.10.0 numpy-2.2.6 pypdf-6.1.3 types-pyyaml-6.0.12.20250915
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\sushi\AppData\Roaming\Python\Python311\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\sushi\AppData\Roaming\Python\Python311\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.

# %%
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(
    url=url, 
    username=username, 
    password=password
)

# %% [markdown]
# Importing data now

# %%
def sanitize(text):
    text = str(text).replace("'","").replace('"','').replace('{','').replace('}', '')
    return text

# Loop through each JSON object and add them to the db
i = 1
for obj in jsonData:
    print(f"{i}. {obj['product_id']} -{obj['relationship']}-> {obj['entity_value']}")
    i+=1
    query = f'''
        MERGE (product:Product {{id: {obj['product_id']}}})
        ON CREATE SET product.name = "{sanitize(obj['product'])}", 
                       product.title = "{sanitize(obj['TITLE'])}", 
                       product.bullet_points = "{sanitize(obj['BULLET_POINTS'])}", 
                       product.size = {sanitize(obj['PRODUCT_LENGTH'])}

        MERGE (entity:{obj['entity_type']} {{value: "{sanitize(obj['entity_value'])}"}})

        MERGE (product)-[:{obj['relationship']}]->(entity)
        '''
    graph.query(query)
# Out:
# 1. 1925202 -hasCategory-> home decoration
# 2. 1925202 -hasBrand-> ArtzFolio
# 3. 1925202 -hasCharacteristic-> Eyelets
# 4. 1925202 -hasCharacteristic-> Tie Back
# 5. 1925202 -hasCharacteristic-> 100% opaque
# 6. 1925202 -hasCharacteristic-> Heavy premium cotton canvas fabric
# 7. 1925202 -hasMeasurement-> Width 4.5 feet (54 inch) Height 5 feet (60 inch)
# 8. 1925202 -hasColor-> Multicolour
# 9. 1925202 -isFor-> adults
# 10. 2673191 -hasCategory-> clothing
# 11. 2673191 -hasBrand-> Marks & Spencer
# 12. 2673191 -hasColor-> Navy Mix
# 13. 2673191 -hasCharacteristic-> 100% cotton
# 14. 2673191 -hasCharacteristic-> Ribbing
# 15. 2673191 -hasMeasurement-> 9-10Y
# 16. 2673191 -isFor-> children
# 17. 2765088 -hasCategory-> automotive accessories
# 18. 2765088 -hasCharacteristic-> Loud Dual Tone Trumpet
# 19. 2765088 -hasCharacteristic-> High Quality
# 20. 2765088 -hasCharacteristic-> High Intensity Horn Sound
# 21. 2765088 -hasCharacteristic-> Professional installation required
# 22. 2765088 -hasColor-> Red
# 23. 2765088 -hasMeasurement-> 12V
# 24. 2765088 -hasMeasurement-> 130 dB
# 25. 2765088 -hasBrand-> PRIKNIK
# 26. 2765088 -isFor-> adults
# 27. 1594019 -hasCategory-> women clothing
# 28. 1594019 -hasBrand-> ALISHAH
# 29. 1594019 -hasCharacteristic-> 4 ways stretchable
# 30. 1594019 -hasCharacteristic-> Elasticized Waist Band
# 31. 1594019 -hasCharacteristic-> Slim Fit
# 32. 1594019 -hasCharacteristic-> Bubble free fabric
# 33. 1594019 -hasCharacteristic-> High quality stitching
# 34. 1594019 -hasCharacteristic-> Bio Wash
# 35. 1594019 -hasCharacteristic-> Skin-friendly fabric
# 36. 1594019 -hasMeasurement-> Medium: 28 - 30 inch
# 37. 1594019 -hasMeasurement-> Large: 30 - 32 inch
# 38. 1594019 -hasMeasurement-> X-Large: 32 - 34 inch
# 39. 1594019 -hasMeasurement-> 2X-Large: 34 - 38 inch
# 40. 1594019 -isFor-> adults
# 41. 283658 -hasCategory-> book
# 42. 2152929 -hasCategory-> gardening
# 43. 2152929 -hasCategory-> home decoration
# 44. 2152929 -hasBrand-> HINS
# 45. 2152929 -hasCharacteristic-> rustproof
# 46. 2152929 -hasCharacteristic-> durable
# 47. 2152929 -hasColor-> red
# 48. 2152929 -hasMeasurement-> medium
# 49. 2152929 -isFor-> adults
# 50. 413758 -hasCategory-> book
# 51. 2026580 -hasCategory-> home decoration
# 52. 2026580 -hasCategory-> kitchen supply
# 53. 2026580 -hasBrand-> Delavala
# 54. 2026580 -hasCharacteristic-> Self-Adhesive
# 55. 2026580 -hasCharacteristic-> Oil Proof
# 56. 2026580 -hasCharacteristic-> Anti-bacterial
# 57. 2026580 -hasCharacteristic-> Anti-mold
# 58. 2026580 -hasCharacteristic-> Eco-friendly
# 59. 2026580 -hasCharacteristic-> High temperature resistant
# 60. 2026580 -hasMeasurement-> 5 meters
# 61. 2026580 -hasColor-> Silver
# 62. 2026580 -isFor-> adults
# 63. 2050239 -hasCategory-> women's footwear
# 64. 2050239 -hasBrand-> PUMA
# 65. 2050239 -hasCharacteristic-> Leather
# 66. 2050239 -hasCharacteristic-> Rubber
# 67. 2050239 -hasColor-> white
# 68. 2050239 -isFor-> adults
# 69. 2998633 -hasCategory-> home fragrance
# 70. 2998633 -hasBrand-> Hexwell
# 71. 2998633 -hasCharacteristic-> 100% Pure And Natural
# 72. 2998633 -hasMeasurement-> 10ML Each
# 73. 2998633 -hasColor-> Rajnigandha Oil & TeaTree Oil
# 74. 2998633 -isFor-> adults
# 75. 2857066 -hasCategory-> personal protective equipment
# 76. 2857066 -hasCharacteristic-> Anti Fog
# 77. 2857066 -hasCharacteristic-> Windproof
# 78. 2857066 -hasCharacteristic-> Anti Dust
# 79. 2857066 -hasCharacteristic-> Resistant
# 80. 2857066 -hasBrand-> 3NH
# 81. 2857066 -isFor-> adults
# 82. 648364 -hasCategory-> educational materials
# 83. 648364 -isFor-> children
# 84. 1991694 -hasCategory-> books
# 85. 1991694 -hasCharacteristic-> 7 Benefits of Mediterranean Diet
# 86. 1991694 -hasCharacteristic-> 7-Day Plan
# 87. 1991694 -hasCharacteristic-> 70 Yummy Easy Recipes
# 88. 1991694 -isFor-> adults
# 89. 2790448 -hasCategory-> sports & outdoor equipment
# 90. 2790448 -hasBrand-> SEGOVIA
# 91. 2790448 -hasCharacteristic-> Single Walled
# 92. 2790448 -hasCharacteristic-> BPA Free
# 93. 2790448 -hasCharacteristic-> Food Grade Steel
# 94. 2790448 -hasMeasurement-> 1000 ml
# 95. 2790448 -isFor-> adults
# 96. 1810976 -hasCategory-> home decoration
# 97. 1810976 -hasBrand-> Stone & Beam
# 98. 1810976 -hasColor-> blue
# 99. 1810976 -hasMeasurement-> Medium
# 100. 1262926 -hasCategory-> home decoration
# 101. 1262926 -hasCategory-> kitchenware
# 102. 1262926 -hasBrand-> Star Trek
# 103. 1262926 -isFor-> adults
# 104. 1491106 -hasCategory-> motorcycle gear
# 105. 1491106 -hasBrand-> Steelbird
# 106. 1491106 -hasCharacteristic-> High Impact ABS Material Shell
# 107. 1491106 -hasCharacteristic-> Replaceable and washable interior
# 108. 1491106 -hasCharacteristic-> Multi-layer EPS (Thermocol)
# 109. 1491106 -hasCharacteristic-> Italian Design Hygienic Interior
# 110. 1491106 -hasCharacteristic-> Multipored Breathable Pedding
# 111. 1491106 -hasCharacteristic-> Neck Protector For Extra Comfort
# 112. 1491106 -hasCharacteristic-> Anti-bacteria coating
# 113. 1491106 -hasCharacteristic-> Anti Allergic Interior
# 114. 1491106 -hasMeasurement-> 580 mm (M)
# 115. 1491106 -hasColor-> Glossy Black and Blue
# 116. 1491106 -isFor-> adults
# 117. 1543564 -hasCategory-> footwear
# 118. 1543564 -hasBrand-> Kenneth Cole REACTION
# 119. 1543564 -hasColor-> cognac
# 120. 1543564 -hasMeasurement-> 10 M US
# 121. 1543564 -hasCharacteristic-> Burnished metal center bit
# 122. 1543564 -hasCharacteristic-> Slightly padded Footbed
# 123. 1543564 -isFor-> adults
# 124. 1045826 -hasCategory-> kitchen supply
# 125. 1045826 -hasBrand-> Cybrtrayd
# 126. 1045826 -hasCharacteristic-> Exclusive Cybrtrayd Copyrighted Chocolate Molding Instructions
# 127. 1045826 -isFor-> adults
# 128. 2964715 -hasCategory-> phone accessories
# 129. 2964715 -hasCharacteristic-> Compatible with iPhone 13
# 130. 2964715 -hasCharacteristic-> supports wireless charging
# 131. 2964715 -hasCharacteristic-> shockproof
# 132. 2964715 -hasCharacteristic-> scratch-resistant
# 133. 2964715 -hasCharacteristic-> raised screen and camera edges
# 134. 2964715 -hasCharacteristic-> anti-yellow
# 135. 2964715 -hasColor-> blue
# 136. 2964715 -hasColor-> orange
# 137. 2964715 -isFor-> adults
# 138. 2120903 -hasCategory-> incense
# 139. 2120903 -hasBrand-> JSR CART
# 140. 2120903 -hasCharacteristic-> Natural & Herbal
# 141. 2120903 -hasCharacteristic-> Low Smoke
# 142. 2120903 -hasColor-> rose
# 143. 2120903 -isFor-> adults
# 144. 879159 -hasCategory-> camera accessories
# 145. 879159 -hasBrand-> Lowepro
# 146. 879159 -hasColor-> black
# 147. 879159 -isFor-> adults
# 148. 2273102 -hasCategory-> jewelry
# 149. 2273102 -hasBrand-> Redgem
# 150. 2273102 -hasCharacteristic-> Natural Amethyst
# 151. 2273102 -hasCharacteristic-> Pure Sterling Silver
# 152. 2273102 -hasCharacteristic-> Nickel Free
# 153. 2273102 -hasCharacteristic-> Lead Free
# 154. 2273102 -hasCharacteristic-> Non-Allergic
# 155. 2273102 -hasCharacteristic-> S925 Mark
# 156. 2273102 -isFor-> adults
# 157. 2273102 -hasColor-> purple
# 158. 1724966 -hasCategory-> clothing
# 159. 1724966 -hasBrand-> BaronHong
# 160. 1724966 -hasColor-> black
# 161. 1724966 -hasCharacteristic-> strong elastic band
# 162. 1724966 -hasCharacteristic-> comfortable
# 163. 1724966 -hasCharacteristic-> do not fade
# 164. 1724966 -hasMeasurement-> 2XL
# 165. 1724966 -isFor-> adults
# 166. 854763 -hasCategory-> toy vehicles
# 167. 854763 -hasBrand-> Hot Wheels
# 168. 854763 -hasColor-> white
# 169. 854763 -hasMeasurement-> 1:64 Scale
# 170. 854763 -isFor-> children
# 171. 2075497 -hasCategory-> home decoration
# 172. 2075497 -hasMeasurement-> Height 55 cm, Width 22 cm
# 173. 2075497 -hasCharacteristic-> Handcrafted
# 174. 2075497 -hasCharacteristic-> Decorative
# 175. 2075497 -hasCharacteristic-> Feng Shui
# 176. 2075497 -hasColor-> Multicolour
# 177. 2075497 -isFor-> adults
# 178. 2367805 -hasCategory-> vehicle tracker
# 179. 2367805 -hasBrand-> GEOSHADOW
# 180. 2367805 -hasCharacteristic-> High-end
# 181. 2367805 -hasCharacteristic-> Small
# 182. 2367805 -hasCharacteristic-> Light Weight
# 183. 2367805 -hasCharacteristic-> Anti Theft
# 184. 2367805 -hasCharacteristic-> Waterproof
# 185. 2367805 -hasCharacteristic-> Real time Live Location
# 186. 2367805 -hasCharacteristic-> Dual SIM
# 187. 2367805 -hasCharacteristic-> Bluetooth Connectivity
# 188. 2367805 -hasCharacteristic-> SOS
# 189. 2367805 -hasCharacteristic-> Geo-Fence
# 190. 2367805 -hasCharacteristic-> Vibration
# 191. 2367805 -hasCharacteristic-> Movement alarms and notification
# 192. 2367805 -hasMeasurement-> <10 Meters
# 193. 2367805 -hasMeasurement-> 10-30V DC
# 194. 2367805 -hasMeasurement-> 170mAh
# 195. 2367805 -isFor-> adults
# 196. 1188856 -hasCategory-> furniture
# 197. 1188856 -hasBrand-> Zinus
# 198. 1188856 -hasMeasurement-> 60" W x 80" L x 18" H
# 199. 1188856 -hasCharacteristic-> Under-bed Storage
# 200. 1188856 -hasCharacteristic-> Strong
# 201. 1188856 -hasCharacteristic-> Sturdy
# 202. 1188856 -hasCharacteristic-> Quiet Noise-Free
# 203. 1188856 -hasCharacteristic-> No Box Spring Required
# 204. 1188856 -hasCharacteristic-> Easy Storage
# 205. 1188856 -hasCharacteristic-> Floor Protection
# 206. 1188856 -isFor-> adults
# 207. 2165448 -hasCategory-> book
# 208. 292637 -hasCategory-> books
# 209. 1955999 -hasCategory-> women clothing
# 210. 1955999 -hasCharacteristic-> A-Line
# 211. 1955999 -hasCharacteristic-> Deep V-Neck
# 212. 1955999 -hasCharacteristic-> Sleeveless
# 213. 1955999 -hasCharacteristic-> Open Back
# 214. 1955999 -hasCharacteristic-> Back Zipper
# 215. 1955999 -hasCharacteristic-> Shimmering Sequin Bodice
# 216. 1955999 -hasCharacteristic-> with Pockets
# 217. 1955999 -hasColor-> hot pink
# 218. 1955999 -hasBrand-> YinanLi Dress
# 219. 1955999 -isFor-> adults
# 220. 2543433 -hasCategory-> patio furniture
# 221. 2543433 -hasBrand-> Decor Therapy
# 222. 2543433 -hasCharacteristic-> comfortable cushioning
# 223. 2543433 -hasCharacteristic-> Durable outdoor fabric
# 224. 2543433 -hasCharacteristic-> Cleans easily
# 225. 2543433 -hasMeasurement-> 20 in. W x 19.5 in. D x 5 in. H
# 226. 2543433 -hasColor-> Wheat
# 227. 1108294 -hasCategory-> water sports equipment
# 228. 1108294 -hasBrand-> Full Throttle
# 229. 1108294 -hasColor-> red
# 230. 1108294 -hasMeasurement-> 70 inches
# 231. 1108294 -isFor-> adults
# 232. 2535064 -hasCategory-> women clothing
# 233. 2535064 -hasCharacteristic-> Oversized style
# 234. 2535064 -hasCharacteristic-> Long Batwing Sleeve
# 235. 2535064 -hasCharacteristic-> Spilt Hem
# 236. 2535064 -hasCharacteristic-> Tunic
# 237. 2535064 -hasCharacteristic-> Pullover
# 238. 2535064 -hasCharacteristic-> Knit Tops
# 239. 2535064 -hasBrand-> LILLUSORY
# 240. 2535064 -hasColor-> Dark Apricot
# 241. 2535064 -hasMeasurement-> X-Small
# 242. 2535064 -isFor-> adults
# 243. 1962527 -hasCategory-> office supply
# 244. 1962527 -hasMeasurement-> 5" W × 7" H
# 245. 1962527 -hasCharacteristic-> Day-at-a-time interior layout
# 246. 1962527 -hasCharacteristic-> Hardcover
# 247. 1962527 -hasCharacteristic-> elastic closure
# 248. 1962527 -hasCharacteristic-> memento pouch
# 249. 1962527 -hasCharacteristic-> 2 ribbon markers
# 250. 1962527 -hasCharacteristic-> monthly and yearly calendars
# 251. 1962527 -hasCharacteristic-> national and international holidays
# 252. 1962527 -hasCharacteristic-> removable address book
# 253. 1962527 -hasCharacteristic-> conversion tables
# 254. 1962527 -hasCharacteristic-> international dialing codes
# 255. 1962527 -hasCharacteristic-> world time zones
# 256. 1962527 -hasCharacteristic-> additional note-taking pages
# 257. 1962527 -hasBrand-> Paperblanks
# 258. 1962527 -hasColor-> deep blue
# 259. 1962527 -isFor-> adults
# 260. 213498 -hasCategory-> books
# 261. 213498 -hasCharacteristic-> Soul Growth Inspirations
# 262. 213498 -isFor-> adults
# 263. 2779227 -hasCategory-> mobile accessories
# 264. 2779227 -hasBrand-> Cleok Associate
# 265. 2779227 -hasCharacteristic-> environment friendly
# 266. 2779227 -hasCharacteristic-> recyclable
# 267. 2779227 -hasCharacteristic-> accurate fitting
# 268. 2779227 -hasCharacteristic-> drop protection
# 269. 2779227 -hasCharacteristic-> sanitized
# 270. 2779227 -hasColor-> multicolor
# 271. 2779227 -isFor-> adults
# 272. 1519827 -hasCategory-> women clothing
# 273. 1519827 -hasBrand-> Pooplu
# 274. 1519827 -hasCharacteristic-> 100 % Cotton
# 275. 1519827 -hasCharacteristic-> 180 GSM
# 276. 1519827 -hasCharacteristic-> Regular Fit
# 277. 1519827 -hasCharacteristic-> Stylish
# 278. 1519827 -hasCharacteristic-> Casual
# 279. 1519827 -hasColor-> pink
# 280. 1519827 -hasColor-> yellow
# 281. 1519827 -hasColor-> dark pink
# 282. 1519827 -isFor-> adults
# 283. 993228 -hasCategory-> music
# 284. 1329311 -hasCategory-> party supplies
# 285. 1329311 -hasMeasurement-> 30 oz
# 286. 1329311 -hasBrand-> Amscan
# 287. 1329311 -hasColor-> Caribbean Blue
# 288. 1329311 -hasCharacteristic-> High quality
# 289. 1329311 -isFor-> adults
# 290. 1501832 -hasCategory-> sporting goods
# 291. 1501832 -hasBrand-> adidas
# 292. 1501832 -hasColor-> black
# 293. 1501832 -hasMeasurement-> 7.5
# 294. 1501832 -isFor-> adults
# 295. 1706369 -hasCategory-> home decoration
# 296. 1706369 -hasMeasurement-> 52 X 63 Inch
# 297. 1706369 -hasColor-> Light Grey
# 298. 1706369 -hasCharacteristic-> Total Room Darkening
# 299. 1706369 -hasCharacteristic-> Thermal
# 300. 1706369 -hasCharacteristic-> Grommet
# 301. 1706369 -hasCharacteristic-> Double Layers
# 302. 1706369 -hasCharacteristic-> Thick Soundproof
# 303. 1706369 -hasCharacteristic-> Energy Saving
# 304. 1706369 -hasBrand-> HOMEIDEAS
# 305. 1706369 -isFor-> adults
# 306. 2514546 -hasCategory-> art craft
# 307. 2514546 -hasCharacteristic-> Soft
# 308. 2514546 -hasCharacteristic-> Fingering
# 309. 2514546 -hasCharacteristic-> 3 ply
# 310. 2514546 -hasMeasurement-> 300 gm
# 311. 2514546 -hasMeasurement-> 250 meters per 100 gm
# 312. 2514546 -hasBrand-> Oswal
# 313. 2514546 -hasColor-> Multi
# 314. 2514546 -hasColor-> Black
# 315. 2514546 -hasColor-> Violet
# 316. 2514546 -hasColor-> Blue
# 317. 2514546 -hasColor-> White
# 318. 2514546 -hasColor-> Red
# 319. 2514546 -hasColor-> Green
# 320. 2514546 -isFor-> adults
# 321. 2632764 -hasCategory-> figurine decoration
# 322. 2632764 -hasCategory-> model collection
# 323. 2632764 -isFor-> adults
# 324. 1033263 -hasCategory-> men clothing
# 325. 1033263 -hasBrand-> Fruit of the Loom
# 326. 1033263 -isFor-> adults
# 327. 669543 -hasCategory-> books
# 328. 2749965 -hasCategory-> home decoration
# 329. 2749965 -hasBrand-> PosterHub
# 330. 2749965 -hasMeasurement-> 12 x 18 Inch
# 331. 2749965 -hasCharacteristic-> Matte Finish
# 332. 2749965 -hasCharacteristic-> UV resistant inks
# 333. 2749965 -hasColor-> Multicolor
# 334. 2749965 -isFor-> adults
# 335. 535662 -hasCategory-> food
# 336. 535662 -hasCharacteristic-> Free from the Top 14 Allergens
# 337. 535662 -isFor-> adults
# 338. 1471735 -hasCategory-> activewear
# 339. 1471735 -hasBrand-> Fihapyli
# 340. 1471735 -hasCharacteristic-> Mesh Back
# 341. 1471735 -hasCharacteristic-> Racerback
# 342. 1471735 -hasCharacteristic-> Backless
# 343. 1471735 -hasCharacteristic-> Sleeveless
# 344. 1471735 -hasCharacteristic-> Quick-drying
# 345. 1471735 -hasCharacteristic-> Stretchable
# 346. 1471735 -hasCharacteristic-> Breathable
# 347. 1471735 -hasCharacteristic-> Soft
# 348. 1471735 -hasCharacteristic-> Lightweight
# 349. 1471735 -hasCharacteristic-> Skin Friendly
# 350. 1471735 -hasCharacteristic-> Moisture Wicking
# 351. 1471735 -hasColor-> Green
# 352. 1471735 -hasMeasurement-> M
# 353. 1471735 -isFor-> adults
# 354. 518364 -hasCategory-> office supply
# 355. 518364 -hasCategory-> stationery
# 356. 518364 -isFor-> adults
# 357. 2278606 -hasCategory-> electronics
# 358. 2278606 -hasCharacteristic-> Multifunctional use
# 359. 2278606 -hasCharacteristic-> Strict quality control
# 360. 2278606 -hasCharacteristic-> High safety factor
# 361. 2278606 -hasCharacteristic-> Small size
# 362. 2278606 -hasCharacteristic-> With memory card slot
# 363. 2278606 -hasMeasurement-> 480X320 HD resolution
# 364. 2278606 -hasMeasurement-> 3.5 inch
# 365. 2278606 -hasMeasurement-> 48.96 x 73.44mm effective display area
# 366. 2278606 -hasMeasurement-> 56.34 x 98mm module PCB floor size
# 367. 2278606 -hasBrand-> ILI9488 driver chip
# 368. 2278606 -isFor-> adults
# 369. 1680776 -hasCategory-> home organization
# 370. 1680776 -hasCharacteristic-> Foldable
# 371. 1680776 -hasCharacteristic-> Breathable
# 372. 1680776 -hasCharacteristic-> Eco-Friendly
# 373. 1680776 -hasCharacteristic-> with Clear Window
# 374. 1680776 -hasCharacteristic-> Dual Zippers
# 375. 1680776 -hasCharacteristic-> 4 Strong Handles
# 376. 1680776 -hasColor-> White Grey
# 377. 1680776 -hasColor-> Coffee with Lantern Printing
# 378. 1680776 -hasMeasurement-> 39.37"x19.68"x5.90" inches
# 379. 1680776 -isFor-> adults
# 380. 1680776 -hasBrand-> homyfort
# 381. 2694373 -hasCategory-> kitchen storage
# 382. 2694373 -hasBrand-> Prigo Enterprise
# 383. 2694373 -hasCharacteristic-> with Handles
# 384. 2694373 -hasCharacteristic-> Airtight Lid
# 385. 2694373 -hasCharacteristic-> Unbreakable
# 386. 2694373 -hasMeasurement-> 1100ml
# 387. 2694373 -hasColor-> Peach
# 388. 2694373 -hasColor-> Blue
# 389. 2694373 -hasColor-> White
# 390. 2694373 -isFor-> adults
# 391. 916467 -hasCategory-> automotive parts
# 392. 916467 -hasBrand-> Luber-finer
# 393. 916467 -hasCharacteristic-> Micro-glass synthetic and cellulose medias
# 394. 916467 -hasCharacteristic-> high filtering efficiency
# 395. 916467 -hasCharacteristic-> dirt-holding capacity
# 396. 916467 -hasCharacteristic-> Heavy-duty seamless steel shell
# 397. 916467 -hasCharacteristic-> unequaled burst and pulse-fatigue strength
# 398. 916467 -hasCharacteristic-> Extra-strength spiral core
# 399. 916467 -hasCharacteristic-> resists high-pressure surges
# 400. 916467 -hasCharacteristic-> Durable vibration resistant gasket
# 401. 916467 -hasCharacteristic-> provides positive seal
# 402. 916467 -hasCharacteristic-> Real-time filtration solutions
# 403. 916467 -hasCharacteristic-> reduce engine wear
# 404. 916467 -hasCharacteristic-> downtime
# 405. 916467 -hasCharacteristic-> operating costs
# 406. 1153854 -hasCategory-> accessories
# 407. 1153854 -hasCharacteristic-> Iron-On
# 408. 1153854 -hasColor-> black
# 409. 1153854 -isFor-> adults
# 410. 2271956 -hasCategory-> mobile accessory
# 411. 2271956 -hasBrand-> Compatible with OnePlus
# 412. 2271956 -hasCharacteristic-> Matte Laminated
# 413. 2271956 -hasCharacteristic-> Easy to install
# 414. 2271956 -hasCharacteristic-> 100% removable
# 415. 2271956 -hasCharacteristic-> Bubble Proof
# 416. 2271956 -hasCharacteristic-> Waterproof
# 417. 2271956 -hasColor-> Blue Gold Marble
# 418. 2271956 -isFor-> adults
# 419. 1218493 -hasCategory-> climbing gear
# 420. 1218493 -hasBrand-> Mad Rock
# 421. 1218493 -hasCharacteristic-> moderately stiff
# 422. 1218493 -hasCharacteristic-> slightly downturned
# 423. 1218493 -hasCharacteristic-> SynFlex upper
# 424. 1218493 -hasCharacteristic-> gore elastic closure
# 425. 1218493 -hasCharacteristic-> Science Friction rubber
# 426. 1218493 -hasCharacteristic-> toe-hooking prowess
# 427. 1218493 -hasColor-> blue
# 428. 1218493 -hasMeasurement-> 9.5
# 429. 1218493 -isFor-> adults
# 430. 1662896 -hasCategory-> home decoration
# 431. 1662896 -hasCharacteristic-> 24K Gold Printed
# 432. 1662896 -hasCharacteristic-> Scratch proof printing
# 433. 1662896 -hasCharacteristic-> Made with German Colors
# 434. 1662896 -hasMeasurement-> 7 inch
# 435. 1662896 -hasBrand-> Real Art.
# 436. 1662896 -isFor-> adults
# 437. 2763742 -hasCategory-> women clothing
# 438. 2763742 -hasBrand-> Attiris
# 439. 2763742 -hasCharacteristic-> Semi-Stitched
# 440. 2763742 -hasCharacteristic-> Embroidered
# 441. 2763742 -hasMeasurement-> Waist - Up to 42 Inches
# 442. 2763742 -hasMeasurement-> Length - 42 Inches
# 443. 2763742 -hasMeasurement-> Lehenga Flair - 3 Meter
# 444. 2763742 -hasMeasurement-> Dupatta Length - 2.5m
# 445. 2763742 -hasColor-> green
# 446. 2763742 -isFor-> adults
# 447. 331813 -hasCategory-> book
# 448. 2464480 -hasCategory-> skincare
# 449. 2464480 -hasBrand-> GLAVON ADS
# 450. 2464480 -hasCharacteristic-> Natural Apricot Extract
# 451. 2464480 -hasMeasurement-> 200 gm
# 452. 2464480 -hasCategory-> makeup
# 453. 2464480 -hasBrand-> MN
# 454. 2464480 -hasCharacteristic-> Rose Extract
# 455. 2464480 -hasColor-> Dark Ivory
# 456. 2464480 -hasMeasurement-> Shade C
# 457. 2464480 -isFor-> adults
# 458. 1603707 -hasCategory-> laptop accessories
# 459. 1603707 -hasBrand-> RADANYA
# 460. 1603707 -hasCharacteristic-> protects from dirt
# 461. 1603707 -hasCharacteristic-> protects from minor scratches
# 462. 1603707 -hasCharacteristic-> prevents dullness
# 463. 1603707 -hasCharacteristic-> easy to install & remove
# 464. 1603707 -hasCharacteristic-> leaves no residue
# 465. 1603707 -hasColor-> multicolor
# 466. 1603707 -hasMeasurement-> 15 inches x 10 inches
# 467. 1603707 -isFor-> adults
# 468. 1571736 -hasCategory-> jewelry
# 469. 1571736 -hasCharacteristic-> Flat Pipe Cut
# 470. 1571736 -hasCharacteristic-> High Polished
# 471. 1571736 -hasCharacteristic-> Comfort Fit
# 472. 1571736 -hasCharacteristic-> Lightweight Design
# 473. 1571736 -hasCharacteristic-> Hypoallergenic
# 474. 1571736 -hasCharacteristic-> Scratch resistant
# 475. 1571736 -hasMeasurement-> 6mm width
# 476. 1571736 -hasMeasurement-> 2mm thickness
# 477. 1571736 -hasBrand-> MJ Metals Jewelry
# 478. 1571736 -hasColor-> white
# 479. 1571736 -isFor-> adults
# 480. 1527911 -hasCategory-> office supply
# 481. 1527911 -hasBrand-> ArtzFolio
# 482. 1527911 -hasCharacteristic-> Flexible mounting
# 483. 1527911 -hasCharacteristic-> self-healing adaptive technology
# 484. 1527911 -hasCharacteristic-> natural finish
# 485. 1527911 -hasCharacteristic-> light-weight
# 486. 1527911 -hasCharacteristic-> durable
# 487. 1527911 -hasMeasurement-> 28 x 23.6 inch
# 488. 1527911 -hasMeasurement-> 71 x 60 cms
# 489. 1527911 -hasColor-> black
# 490. 1527911 -isFor-> adults
# 491. 993385 -hasCategory-> office supply
# 492. 993385 -hasMeasurement-> A3
# 493. 993385 -hasBrand-> Exacompta
# 494. 993385 -hasColor-> black
# 495. 993385 -hasCharacteristic-> 20 Pockets
# 496. 993385 -isFor-> adults
# 497. 1509561 -hasCategory-> mobile accessories
# 498. 1509561 -hasCharacteristic-> Lightweight
# 499. 1509561 -hasCharacteristic-> Foldable
# 500. 1509561 -hasCharacteristic-> Non-slip
# 501. 1509561 -hasCharacteristic-> Multi-angle adjustable
# 502. 1509561 -hasCharacteristic-> Compatible with all phones and pads
# 503. 1509561 -hasMeasurement-> 130*100*3mm
# 504. 1509561 -hasBrand-> Oxza
# 505. 1509561 -isFor-> adults
# 506. 2349709 -hasCategory-> men's clothing
# 507. 2349709 -hasBrand-> Red Tape
# 508. 2349709 -hasColor-> Grey
# 509. 2349709 -hasCharacteristic-> Shell- 95% Polyester 5% Elastane 80gsm
# 510. 2349709 -hasCharacteristic-> Lining - 100% Polyester
# 511. 2349709 -hasCharacteristic-> Padding - 100% Polyester
# 512. 2349709 -isFor-> adults
# 513. 2813917 -hasCategory-> tablet cover
# 514. 2813917 -hasBrand-> Acm
# 515. 2813917 -hasCharacteristic-> Magnetic Closure
# 516. 2813917 -hasCharacteristic-> Stand Feature
# 517. 2813917 -hasColor-> green
# 518. 2813917 -isFor-> adults
# 519. 416919 -hasCategory-> books
# 520. 499846 -hasCategory-> office supply
# 521. 499846 -hasCharacteristic-> Dated
# 522. 499846 -hasMeasurement-> Aug 2019 - Aug 2020
# 523. 499846 -isFor-> adults
# 524. 1233616 -hasCategory-> women clothing
# 525. 1233616 -hasCharacteristic-> Loose fit
# 526. 1233616 -hasCharacteristic-> flowy wide leg
# 527. 1233616 -hasCharacteristic-> lightweight
# 528. 1233616 -hasCharacteristic-> 1 side pocket
# 529. 1233616 -hasCharacteristic-> elastic around the ankles
# 530. 1233616 -hasCharacteristic-> handmade
# 531. 1233616 -hasCharacteristic-> ethically made
# 532. 1233616 -hasCharacteristic-> Fair Trade
# 533. 1233616 -hasBrand-> Lofbaz
# 534. 1233616 -hasColor-> purple
# 535. 1233616 -isFor-> adults
# 536. 1233616 -hasMeasurement-> Waist circumference: 22.8 - 66.1 inches
# 537. 1233616 -hasMeasurement-> Leg Length: 41.3 inches
# 538. 1325580 -hasCategory-> women clothing
# 539. 1325580 -hasBrand-> Wacoal
# 540. 1325580 -hasMeasurement-> 38C
# 541. 1325580 -hasColor-> red
# 542. 1325580 -hasCharacteristic-> seamless
# 543. 1325580 -isFor-> adults
# 544. 1099232 -hasCategory-> computer accessories
# 545. 1099232 -hasBrand-> Startech.com
# 546. 1461415 -hasCategory-> personal care
# 547. 1461415 -hasBrand-> Ozette
# 548. 1461415 -hasCharacteristic-> Super Soft
# 549. 1461415 -hasCharacteristic-> Special Tapered Filaments
# 550. 1461415 -hasCharacteristic-> Anti-Bacterial Container
# 551. 1461415 -hasCharacteristic-> Washable and Reusable
# 552. 1461415 -hasColor-> Assorted Colors
# 553. 1461415 -isFor-> adults
# 554. 1888716 -hasCategory-> craft supplies
# 555. 1888716 -hasCharacteristic-> Metallic
# 556. 1888716 -hasCharacteristic-> Wool
# 557. 1888716 -hasCharacteristic-> Acrylic
# 558. 1888716 -hasMeasurement-> 200gr 1100 yds
# 559. 1888716 -hasMeasurement-> 500 mt (550 yds) per ball
# 560. 1888716 -hasMeasurement-> 3.53 Oz per skein
# 561. 1888716 -hasMeasurement-> Knitting needle size: 3-6 mm
# 562. 1888716 -hasMeasurement-> Crochet Hook 2-4 mm
# 563. 1888716 -hasBrand-> Alize
# 564. 1888716 -hasColor-> Cream
# 565. 1888716 -isFor-> adults
# 566. 2714665 -hasCategory-> bicycle accessories
# 567. 2714665 -hasBrand-> Trendy Retail
# 568. 2714665 -hasMeasurement-> 11 x 8 cm
# 569. 2714665 -hasCharacteristic-> Max Loading is 35kg
# 570. 2714665 -hasCharacteristic-> durable and wear-resisting
# 571. 2714665 -hasColor-> red
# 572. 2714665 -isFor-> adults
# 573. 2403589 -hasCategory-> home decor
# 574. 2403589 -hasMeasurement-> 18x18 inches
# 575. 2403589 -hasBrand-> Wyooxoo
# 576. 2403589 -hasCharacteristic-> Top Quality of Linen Fabric
# 577. 2403589 -hasCharacteristic-> breathable
# 578. 2403589 -hasCharacteristic-> comfortable
# 579. 2403589 -hasCharacteristic-> durable
# 580. 2403589 -hasCharacteristic-> HD digital printing
# 581. 2403589 -hasCharacteristic-> invisible zipper design
# 582. 2403589 -hasCharacteristic-> machine washable
# 583. 2403589 -isFor-> adults
# 584. 2919319 -hasCategory-> women clothing
# 585. 2919319 -hasCharacteristic-> light in weight
# 586. 2919319 -hasCharacteristic-> Fancy
# 587. 2919319 -hasColor-> white
# 588. 2919319 -hasMeasurement-> 2.25 meters
# 589. 2919319 -hasCharacteristic-> Printed Work
# 590. 2919319 -hasCharacteristic-> star zari
# 591. 2919319 -hasCharacteristic-> jhalar lace
# 592. 2919319 -hasCharacteristic-> Soft Chiffon fabric
# 593. 2919319 -isFor-> adults
# 594. 2894923 -hasCategory-> car accessories
# 595. 2894923 -hasBrand-> GlobalNiche
# 596. 2894923 -hasColor-> red
# 597. 2894923 -isFor-> adults
# 598. 1008258 -hasCategory-> clothing
# 599. 1008258 -hasBrand-> The Mountain
# 600. 1008258 -hasCharacteristic-> Preshrunk
# 601. 1008258 -hasCharacteristic-> Environmentally friendly
# 602. 1008258 -hasCharacteristic-> 100% Oekotex Certified
# 603. 1008258 -hasCharacteristic-> Non-Toxic Water-Based Inks
# 604. 1008258 -hasCharacteristic-> Reinforced Double-Stitching
# 605. 1008258 -hasColor-> brown
# 606. 1008258 -hasMeasurement-> Small
# 607. 1008258 -isFor-> adults
# 608. 402457 -hasCategory-> books
# 609. 2535905 -hasCategory-> electronics accessories
# 610. 2535905 -hasCharacteristic-> Hard Shell
# 611. 2535905 -hasCharacteristic-> Shockproof
# 612. 2535905 -hasCharacteristic-> Waterproof
# 613. 2535905 -hasColor-> Pink Marble
# 614. 2535905 -hasMeasurement-> 11.6 inch
# 615. 2535905 -hasMeasurement-> 12 x 8.46 x 0.99 inch
# 616. 2535905 -isFor-> adults
# 617. 2365362 -hasCategory-> planting bulbs
# 618. 2365362 -hasBrand-> Live Green
# 619. 2365362 -hasCharacteristic-> flowering in 50 to 60 days
# 620. 2365362 -hasCharacteristic-> best germination rate
# 621. 2365362 -hasCharacteristic-> suitable for full sun or shade
# 622. 2365362 -hasCharacteristic-> requires normal soil
# 623. 2365362 -hasCharacteristic-> no special care needed
# 624. 2365362 -isFor-> adults
# 625. 2522159 -hasCategory-> clothing
# 626. 2522159 -hasBrand-> Trendy World
# 627. 2522159 -hasCharacteristic-> Hand Wash
# 628. 2522159 -hasCharacteristic-> Machine Wash
# 629. 2522159 -hasCharacteristic-> Full Sleeve
# 630. 2522159 -hasColor-> Colorblock
# 631. 2522159 -isFor-> children
# 632. 250402 -hasCategory-> book
# 633. 352208 -hasCategory-> book
# 634. 969689 -hasCategory-> lawn mower accessories
# 635. 969689 -hasBrand-> John Deere
# 636. 969689 -hasMeasurement-> 5/8"x70-7/8"
# 637. 969689 -hasCharacteristic-> Synchronous
# 638. 969689 -hasCharacteristic-> 225 teeth
# 639. 1942896 -hasCategory-> footwear
# 640. 1942896 -hasBrand-> ASIAN
# 641. 1942896 -hasCharacteristic-> breathable
# 642. 1942896 -hasCharacteristic-> washable
# 643. 1942896 -hasCharacteristic-> quick drying
# 644. 1942896 -hasCharacteristic-> light weight
# 645. 1942896 -hasCharacteristic-> orthopedic soft cushion insole
# 646. 1942896 -hasColor-> black
# 647. 1942896 -isFor-> adults
# 648. 1078966 -hasCategory-> music recording
# 649. 1078966 -hasBrand-> UNUSK CHIN
# 650. 2924892 -hasCategory-> eye care accessories
# 651. 2924892 -hasCharacteristic-> Suitable for traveling
# 652. 2924892 -hasCharacteristic-> Small and easy to carry
# 653. 2924892 -hasCharacteristic-> keeping your contact lens clean and clear
# 654. 2924892 -hasCharacteristic-> Great gift
# 655. 2924892 -hasBrand-> Aqualens
# 656. 2924892 -hasColor-> Moon Blue
# 657. 2924892 -isFor-> adults
# 658. 453984 -hasCategory-> books
# 659. 798322 -hasCategory-> footwear
# 660. 798322 -hasBrand-> K-Swiss
# 661. 798322 -hasColor-> black
# 662. 798322 -hasMeasurement-> 5 M US Toddler
# 663. 798322 -isFor-> children
# 664. 949180 -hasCategory-> bathroom fixture
# 665. 949180 -hasBrand-> Delta
# 666. 949180 -hasColor-> Venetian Bronze
# 667. 2573370 -hasCategory-> phone accessories
# 668. 2573370 -hasBrand-> YES2GOOD
# 669. 2573370 -hasCharacteristic-> Mirror Flip
# 670. 2573370 -hasCharacteristic-> Wireless Charging Compatible
# 671. 2573370 -hasCharacteristic-> Multi-angle Viewing Stand
# 672. 2573370 -hasCharacteristic-> Scratch Resistant
# 673. 2573370 -hasCharacteristic-> Impact Resistant
# 674. 2573370 -hasCharacteristic-> Dust & Debris Resistant
# 675. 2573370 -hasColor-> blue
# 676. 2573370 -isFor-> adults
# 677. 2979917 -hasCategory-> electronics
# 678. 2979917 -hasCharacteristic-> In-Ear
# 679. 2979917 -hasCharacteristic-> Wired
# 680. 2979917 -hasCharacteristic-> With Mic
# 681. 2979917 -hasMeasurement-> 1.2 Metre Cable
# 682. 2979917 -hasCharacteristic-> Metallic Design
# 683. 2979917 -hasCharacteristic-> 10mm Drivers
# 684. 2979917 -hasCharacteristic-> Volume Controller
# 685. 2979917 -hasCharacteristic-> Powerful Audio
# 686. 2979917 -hasCharacteristic-> Built-in Microphone
# 687. 2979917 -hasCharacteristic-> Tangle Resistant Cable
# 688. 2979917 -hasColor-> Black/White
# 689. 2979917 -hasBrand-> NB 2
# 690. 2979917 -hasCharacteristic-> Noise Cancelling
# 691. 2979917 -isFor-> adults
# 692. 2617554 -hasCategory-> phone accessories
# 693. 2617554 -hasBrand-> AAHIL
# 694. 2617554 -hasCharacteristic-> Tough
# 695. 2617554 -hasCharacteristic-> Impact Absorption
# 696. 2617554 -hasCharacteristic-> Easy to install and uninstall
# 697. 2617554 -hasColor-> Multi-Coloured
# 698. 2617554 -isFor-> children
# 699. 2516354 -hasCategory-> toys & games
# 700. 2516354 -hasCharacteristic-> storage compartment
# 701. 2516354 -hasCharacteristic-> jewelry box
# 702. 2516354 -hasCharacteristic-> make up mirror
# 703. 2516354 -hasCharacteristic-> clockwork mechanism
# 704. 2516354 -hasCharacteristic-> no battery needed
# 705. 2516354 -hasColor-> pink
# 706. 2516354 -hasMeasurement-> 17.5*11.5*8.5cm
# 707. 2516354 -hasMeasurement-> 364g
# 708. 2516354 -isFor-> children
# 709. 1250898 -hasCategory-> hardware
# 710. 1250898 -hasMeasurement-> 14 inches
# 711. 1250898 -hasColor-> Silver
# 712. 1250898 -hasBrand-> Vinay
# 713. 1250898 -hasCharacteristic-> Mild steel
# 714. 1250898 -hasCharacteristic-> Smooth movement
# 715. 1250898 -hasCharacteristic-> Full extension
# 716. 1250898 -hasCharacteristic-> Ball cage 2 balls/cage
# 717. 1250898 -hasCharacteristic-> 1 year warranty
# 718. 1250898 -isFor-> adults
# 719. 1954205 -hasCategory-> women clothing
# 720. 1954205 -hasBrand-> Clovia
# 721. 1954205 -hasCharacteristic-> Lightly Padded
# 722. 1954205 -hasCharacteristic-> Wirefree
# 723. 1954205 -hasCharacteristic-> Printed
# 724. 1954205 -hasColor-> black
# 725. 1954205 -hasMeasurement-> 36B
# 726. 1954205 -isFor-> adults
# 727. 1005026 -hasCategory-> books
# 728. 1005026 -hasCategory-> books
# 729. 1005026 -hasCategory-> books
# 730. 1005026 -hasCategory-> books
# 731. 1005026 -hasCategory-> books
# 732. 1005026 -hasCategory-> books
# 733. 2889773 -hasCategory-> bathroom accessory
# 734. 2889773 -hasCharacteristic-> Easy to use
# 735. 2889773 -hasCharacteristic-> Easy to carry
# 736. 2889773 -hasCharacteristic-> Foaming Soap Saver
# 737. 2889773 -hasCharacteristic-> with Drain Holes
# 738. 2889773 -hasCharacteristic-> with Spring
# 739. 2889773 -hasCharacteristic-> Travel Soap Holder
# 740. 2889773 -hasCharacteristic-> Multifunctional
# 741. 2889773 -hasMeasurement-> 12.2cmx7.2cmx6.7cm
# 742. 2889773 -hasColor-> Blue
# 743. 2889773 -hasBrand-> AVRT
# 744. 2889773 -isFor-> adults
# 745. 1629663 -hasCategory-> sports clothing
# 746. 1629663 -hasBrand-> Liakada
# 747. 1629663 -hasCharacteristic-> Scoop Neckline
# 748. 1629663 -hasCharacteristic-> Integrated bra shelf liner
# 749. 1629663 -hasCharacteristic-> Adjustable straps
# 750. 1629663 -hasCharacteristic-> Criss-cross straps
# 751. 1629663 -hasMeasurement-> 92% Nylon 8% Spandex
# 752. 1629663 -hasColor-> black
# 753. 1629663 -isFor-> children
# 754. 1286350 -hasCategory-> anime accessories
# 755. 1286350 -hasCharacteristic-> Licensed product
# 756. 1286350 -hasCharacteristic-> Cool looking
# 757. 1286350 -hasMeasurement-> ~2" - 3" Tall
# 758. 1286350 -hasBrand-> One Piece
# 759. 37215 -hasCategory-> books
# 760. 37215 -hasBrand-> Pooh Party Time
# 761. 37215 -hasCharacteristic-> Easy Peel
# 762. 37215 -isFor-> children
# 763. 953015 -hasCategory-> office supply
# 764. 953015 -hasBrand-> Sandylion
# 765. 953015 -hasMeasurement-> 2 Sheets
# 766. 953015 -hasCharacteristic-> 55 stickers
# 767. 953015 -isFor-> children
# 768. 28328 -hasCategory-> book
# 769. 28328 -hasCharacteristic-> Classic Reprint
# 770. 63631 -hasCategory-> books
# 771. 63631 -isFor-> adults
# 772. 2782586 -hasCategory-> mobile accessories
# 773. 2782586 -hasBrand-> Bhaicover
# 774. 2782586 -hasCharacteristic-> 3D Printed
# 775. 2782586 -hasCharacteristic-> Hard Plastic
# 776. 2782586 -hasCharacteristic-> Matte Finish
# 777. 2782586 -hasCharacteristic-> Light Weight
# 778. 2782586 -hasCharacteristic-> Slim
# 779. 2782586 -hasCharacteristic-> Accurate Fitting
# 780. 2782586 -hasCharacteristic-> High Definition Print Quality
# 781. 2782586 -hasCharacteristic-> Sublimation Printing Technology
# 782. 2782586 -hasCharacteristic-> Scratch Resistant
# 783. 2782586 -hasColor-> Vibrant
# 784. 2782586 -isFor-> adults
# 785. 2782586 -hasMeasurement-> iPhone 4/4S/4G Compatible
# 786. 1840290 -hasCategory-> children clothing
# 787. 1840290 -hasCharacteristic-> Semi-Stitched
# 788. 1840290 -hasCharacteristic-> Embroidered
# 789. 1840290 -hasBrand-> Eneric
# 790. 1840290 -hasColor-> blue
# 791. 1840290 -isFor-> children
# 792. 1933839 -hasCategory-> home storage solutions
# 793. 1933839 -hasMeasurement-> 23" W x 13" D x 20" H
# 794. 1933839 -hasCharacteristic-> Heavy Duty
# 795. 1933839 -hasCharacteristic-> Adjustable leveling feet
# 796. 1933839 -hasCharacteristic-> Wire shelves adjustable in 1-inch increments
# 797. 1933839 -hasCharacteristic-> No tools required to assemble
# 798. 1933839 -hasBrand-> Simple Deluxe
# 799. 1933839 -hasColor-> Chrome
# 800. 1933839 -isFor-> adults
# 801. 1705531 -hasCategory-> bedding
# 802. 1705531 -hasCharacteristic-> Extra-long staple polycotton
# 803. 1705531 -hasCharacteristic-> Sustainable
# 804. 1705531 -hasCharacteristic-> Soft
# 805. 1705531 -hasCharacteristic-> Breathable
# 806. 1705531 -hasCharacteristic-> Long-lasting
# 807. 1705531 -hasColor-> yellow
# 808. 1705531 -hasBrand-> Sheets & Covers
# 809. 1705531 -hasMeasurement-> King Size
# 810. 1705531 -isFor-> adults
# 811. 2991833 -hasCategory-> kitchen tools
# 812. 2991833 -hasBrand-> ROY Enterprise
# 813. 2991833 -hasCharacteristic-> Dishwasher Safe
# 814. 2991833 -hasCharacteristic-> Microwave Safe
# 815. 2991833 -hasMeasurement-> 25 cm height
# 816. 2991833 -hasColor-> Black
# 817. 2991833 -isFor-> adults
# 818. 2671387 -hasCategory-> jewelry
# 819. 2671387 -hasBrand-> NMII
# 820. 2671387 -hasCharacteristic-> Non-Precious Metal
# 821. 2671387 -hasCharacteristic-> Zircon Gemstone
# 822. 2671387 -hasCharacteristic-> Pearl Studded
# 823. 2671387 -hasCharacteristic-> Velvet worked
# 824. 2671387 -hasCharacteristic-> Glossy Finished
# 825. 2671387 -hasColor-> Radium
# 826. 2671387 -hasMeasurement-> 2.2 Inches
# 827. 2671387 -isFor-> adults
# 828. 2308229 -hasCategory-> household supplies
# 829. 2308229 -hasCharacteristic-> Easy to use
# 830. 2308229 -hasCharacteristic-> Compact design
# 831. 2308229 -hasCharacteristic-> Lightweight
# 832. 2308229 -hasCharacteristic-> Stainless steel cutter
# 833. 2308229 -hasCharacteristic-> Durable
# 834. 2308229 -hasCharacteristic-> Easy cleaning
# 835. 2308229 -hasMeasurement-> 150 * 125 * 63mm
# 836. 2308229 -hasMeasurement-> 280g
# 837. 2308229 -hasMeasurement-> 180 * 130 * 80mm
# 838. 2308229 -hasBrand-> ABS
# 839. 2308229 -hasColor-> Red
# 840. 2308229 -isFor-> adults
# 841. 941830 -hasCategory-> women clothing
# 842. 941830 -hasBrand-> Gossard
# 843. 941830 -hasCharacteristic-> Sheer smooth
# 844. 941830 -hasCharacteristic-> no vpl
# 845. 941830 -hasColor-> nude
# 846. 941830 -hasMeasurement-> Large
# 847. 941830 -isFor-> adults
# 848. 2111674 -hasCategory-> musical instruments accessories
# 849. 2111674 -hasBrand-> PERRI'S LEATHERS LTD
# 850. 2111674 -hasCharacteristic-> adjustable lengths
# 851. 2111674 -hasMeasurement-> 2 inches wide
# 852. 2111674 -hasMeasurement-> 39 to 58 inches long
# 853. 2111674 -hasCharacteristic-> medium celluloid
# 854. 2111674 -hasMeasurement-> 0.71mm Guitar Picks
# 855. 2111674 -hasCharacteristic-> genuine leather
# 856. 2111674 -hasCharacteristic-> durable plastic knobs
# 857. 2111674 -hasCharacteristic-> Rubber Strap Locks
# 858. 2111674 -hasColor-> blue
# 859. 2111674 -isFor-> adults
# 860. 1712009 -hasCategory-> kitchen dining decor
# 861. 1712009 -hasMeasurement-> 12" X 18"
# 862. 1712009 -hasCharacteristic-> Non-Slip
# 863. 1712009 -hasCharacteristic-> Washable
# 864. 1712009 -hasCharacteristic-> Heat Resistant
# 865. 1712009 -hasCharacteristic-> Machine washable
# 866. 1712009 -hasCharacteristic-> Wrinkle Resistant
# 867. 1712009 -hasBrand-> Wamika
# 868. 1712009 -isFor-> adults
# 869. 912605 -hasCategory-> books
# 870. 912605 -hasCharacteristic-> Reprint
# 871. 912605 -isFor-> adults
# 872. 2301371 -hasCategory-> office supply
# 873. 2301371 -hasBrand-> Dynamic Sales
# 874. 2301371 -hasCharacteristic-> Statistical reading
# 875. 2301371 -hasCharacteristic-> automatic power off
# 876. 2301371 -hasCharacteristic-> counter can be cleared to zero
# 877. 2301371 -hasCharacteristic-> adjustable circle snap
# 878. 2301371 -hasCharacteristic-> low-noise operation
# 879. 2301371 -hasCharacteristic-> light weight
# 880. 2301371 -hasCharacteristic-> portable
# 881. 2301371 -hasColor-> multicolor
# 882. 2301371 -isFor-> adults
# 883. 1922352 -hasCategory-> home decoration
# 884. 1922352 -hasBrand-> AmHoo
# 885. 1922352 -hasCharacteristic-> Semi Sheer
# 886. 1922352 -hasCharacteristic-> Rod Pocket
# 887. 1922352 -hasCharacteristic-> Embroidery Design
# 888. 1922352 -hasCharacteristic-> Machine Washable
# 889. 1922352 -hasMeasurement-> 53 x 84 Inch
# 890. 1922352 -hasColor-> white
# 891. 1922352 -isFor-> adults
# 892. 2687136 -hasCategory-> mobile accessories
# 893. 2687136 -hasCharacteristic-> Full Screen Coverage
# 894. 2687136 -hasCharacteristic-> Anti-Glare
# 895. 2687136 -hasCharacteristic-> Anti-Fingerprint
# 896. 2687136 -hasCharacteristic-> Scratch resistance
# 897. 2687136 -hasCharacteristic-> Bubble free application
# 898. 2687136 -hasCharacteristic-> Oleophobic Coated
# 899. 2687136 -hasCharacteristic-> High definition clarity
# 900. 2687136 -hasCharacteristic-> Rounded edges
# 901. 2687136 -hasCharacteristic-> High oleophobic coating
# 902. 2687136 -hasCharacteristic-> Extreme clarity and responsiveness
# 903. 2687136 -hasMeasurement-> Pack of 2
# 904. 2687136 -isFor-> adults
# 905. 1697336 -hasCategory-> pneumatic mechanical valve
# 906. 1697336 -hasCharacteristic-> 2-Position 2-Way
# 907. 1697336 -hasMeasurement-> G1/8
# 908. 1697336 -hasBrand-> MOV-01
# 909. 1697336 -hasColor-> black
# 910. 1697336 -isFor-> adults
# 911. 2506851 -hasCategory-> car accessories
# 912. 2506851 -hasCharacteristic-> durable
# 913. 2506851 -hasCharacteristic-> light-weight
# 914. 2506851 -hasCharacteristic-> easy to install
# 915. 2506851 -hasMeasurement-> 152cm/60inch length
# 916. 2506851 -hasMeasurement-> 53cm/21inch width
# 917. 2506851 -hasColor-> black
# 918. 2506851 -isFor-> adults
# 919. 2976337 -hasCategory-> wedding decor
# 920. 2976337 -hasCharacteristic-> with Suction Cup
# 921. 2976337 -hasCharacteristic-> battery powered
# 922. 2976337 -hasBrand-> arythe
# 923. 2976337 -hasColor-> Warm White
# 924. 2976337 -hasMeasurement-> 30x10.5cm/11.81x4.13inch
# 925. 2976337 -isFor-> adults
# 926. 2048173 -hasCategory-> footwear
# 927. 2048173 -hasBrand-> Valentino
# 928. 2048173 -hasCharacteristic-> Against Manufacturing Defects
# 929. 2048173 -hasCharacteristic-> 100% genuine leather
# 930. 2048173 -hasCharacteristic-> Long Durable
# 931. 2048173 -hasCharacteristic-> Highly Comfortable
# 932. 2048173 -hasCharacteristic-> Polyurethane (PU) Sole
# 933. 2048173 -hasCharacteristic-> Lace-Up Closure
# 934. 2048173 -hasColor-> brown
# 935. 2048173 -isFor-> adults
# 936. 1730566 -hasCategory-> home decoration
# 937. 1730566 -hasBrand-> Gadgets Wrap
# 938. 1730566 -hasColor-> multicolor
# 939. 1730566 -hasMeasurement-> 29.99 cm x 5.0038 cm x 5.0038 cm
# 940. 1730566 -isFor-> adults
# 941. 2287207 -hasCategory-> office furniture
# 942. 2287207 -hasCharacteristic-> Modern
# 943. 2287207 -hasCharacteristic-> Specialy design for Work from home purpose
# 944. 2287207 -hasMeasurement-> 2*1.5*2 ft
# 945. 2287207 -hasBrand-> GOYAL
# 946. 2287207 -hasMaterial-> Iron frame and wooden top
# 947. 2287207 -isFor-> adults
# 948. 2680505 -hasCategory-> mobile accessories
# 949. 2680505 -hasBrand-> Aegy
# 950. 2680505 -hasCharacteristic-> High Precision
# 951. 2680505 -hasCharacteristic-> Orange Sandstone Pattern
# 952. 2680505 -hasCharacteristic-> High Quality material
# 953. 2680505 -hasCharacteristic-> good adhesive components
# 954. 2680505 -hasCharacteristic-> perfect texture and grip
# 955. 2680505 -hasCharacteristic-> no bubbles
# 956. 2680505 -hasCharacteristic-> Slim
# 957. 2680505 -hasCharacteristic-> light
# 958. 2680505 -hasCharacteristic-> perfect fit
# 959. 2680505 -hasColor-> Orange
# 960. 2680505 -isFor-> adults
# 961. 452565 -hasCategory-> book
# 962. 452565 -isFor-> adults
# 963. 1725917 -hasCategory-> home decoration
# 964. 1725917 -hasCategory-> party decoration
# 965. 1725917 -hasCharacteristic-> Silk
# 966. 1725917 -hasCharacteristic-> Realistic visual effect
# 967. 1725917 -hasCharacteristic-> Handfeel
# 968. 1725917 -hasCharacteristic-> DIY
# 969. 1725917 -hasColor-> Dark Pink
# 970. 1725917 -hasMeasurement-> 20 inch
# 971. 1725917 -hasMeasurement-> 6.3 OZ
# 972. 1725917 -isFor-> adults
# 973. 1984720 -hasCategory-> home office furniture
# 974. 1984720 -hasBrand-> Flash Furniture
# 975. 1984720 -hasCharacteristic-> Rustic Natural
# 976. 1984720 -hasCharacteristic-> Folding
# 977. 1984720 -hasMeasurement-> 36 inches
# 978. 1984720 -hasColor-> black
# 979. 1984720 -isFor-> adults
# 980. 1158744 -hasCategory-> kitchenware
# 981. 1158744 -hasCharacteristic-> Break Resistant
# 982. 1158744 -hasCharacteristic-> Premium Grade
# 983. 1158744 -hasCharacteristic-> Food Grade
# 984. 1158744 -hasMeasurement-> 450 ml
# 985. 1158744 -isFor-> adults
# 986. 1072473 -hasCategory-> automotive parts
# 987. 1072473 -hasBrand-> APDTY
# 988. 1072473 -hasColor-> chrome
# 989. 1072473 -hasColor-> black
# 990. 1072473 -isFor-> adults
# 991. 2588967 -hasCategory-> home decoration
# 992. 2588967 -hasBrand-> ZURU BUNCH
# 993. 2588967 -hasCharacteristic-> 7 Color Changing
# 994. 2588967 -hasCharacteristic-> Liquid Activated
# 995. 2588967 -hasCharacteristic-> Easy Battery Replace
# 996. 2588967 -hasMeasurement-> 250 ml
# 997. 2588967 -hasCharacteristic-> Glow in the Dark
# 998. 2588967 -hasCharacteristic-> Easy to Use
# 999. 2588967 -hasCharacteristic-> Safe Material
# 1000. 2588967 -isFor-> adults
# 1001. 2680290 -hasCategory-> office supply
# 1002. 2680290 -hasBrand-> Aditya Sign
# 1003. 2680290 -hasCharacteristic-> Printed Product
# 1004. 2680290 -hasCharacteristic-> Flexible
# 1005. 2680290 -hasCharacteristic-> Rigid
# 1006. 2680290 -hasCharacteristic-> Light Weight
# 1007. 2680290 -hasCharacteristic-> Dust Proof
# 1008. 2680290 -hasCharacteristic-> Cold Resistant
# 1009. 2680290 -hasCharacteristic-> Water Resistant
# 1010. 2680290 -hasCharacteristic-> Thermal Resistant
# 1011. 2680290 -hasCharacteristic-> Self-Adhesive
# 1012. 2680290 -hasMeasurement-> 8 inch (Width) x 8 inch (Height) x 3 mm Thickness
# 1013. 2680290 -isFor-> adults
# 1014. 1844637 -hasCategory-> women clothing
# 1015. 1844637 -hasCharacteristic-> Touch Screen
# 1016. 1844637 -hasCharacteristic-> Anti-skid
# 1017. 1844637 -hasCharacteristic-> UV Protection
# 1018. 1844637 -hasMeasurement-> One Size
# 1019. 1844637 -hasColor-> Dark Pink
# 1020. 1844637 -isFor-> adults
# 1021. 1945243 -hasCategory-> kitchen utensil
# 1022. 1945243 -hasBrand-> NOHUNT
# 1023. 1945243 -hasCharacteristic-> Swiss made
# 1024. 1945243 -hasCharacteristic-> slip-resistant feet
# 1025. 1945243 -hasCharacteristic-> stainless steel body
# 1026. 1945243 -hasCharacteristic-> comfortable grip
# 1027. 1945243 -hasColor-> red
# 1028. 1945243 -isFor-> adults
# 1029. 2137420 -hasCategory-> home garden balcony decor
# 1030. 2137420 -hasCharacteristic-> High quality
# 1031. 2137420 -hasCharacteristic-> Protective & beautiful
# 1032. 2137420 -hasCharacteristic-> Sturdy & stable
# 1033. 2137420 -hasCharacteristic-> Rust-proofed
# 1034. 2137420 -hasCharacteristic-> Universal Compatibility
# 1035. 2137420 -hasMeasurement-> Weight Upto 45 Kg
# 1036. 2137420 -hasMeasurement-> Height - 8 cm
# 1037. 2137420 -hasMeasurement-> Diameter - 36 cm
# 1038. 2137420 -hasColor-> black
# 1039. 2137420 -isFor-> adults
# 1040. 2155174 -hasCategory-> mobile phone accessories
# 1041. 2155174 -hasCharacteristic-> Slim Fitting
# 1042. 2155174 -hasCharacteristic-> One-Piece Clip-On Case
# 1043. 2155174 -hasCharacteristic-> Gloss Finish Printing
# 1044. 2155174 -hasCharacteristic-> Impact Resistant
# 1045. 2155174 -hasCharacteristic-> Non Toxic
# 1046. 2155174 -hasCharacteristic-> Environmentally Friendly
# 1047. 2155174 -hasCharacteristic-> High-Resolution Printing
# 1048. 2155174 -hasCharacteristic-> UV Printing Technology
# 1049. 2155174 -hasCharacteristic-> Edge To Edge Print
# 1050. 2155174 -hasBrand-> Designer Back Case
# 1051. 2155174 -isFor-> adults
# 1052. 2424672 -hasCategory-> boys clothing
# 1053. 2424672 -hasBrand-> KIDDY STAR
# 1054. 2424672 -hasCharacteristic-> 100% pure cotton
# 1055. 2424672 -hasCharacteristic-> comfortable for all seasons
# 1056. 2424672 -hasCharacteristic-> Bright Colors
# 1057. 2424672 -hasCharacteristic-> Bold graphics
# 1058. 2424672 -hasCharacteristic-> Tag free Crew neck
# 1059. 2424672 -hasCharacteristic-> Regular fit
# 1060. 2424672 -hasColor-> yellow
# 1061. 2424672 -isFor-> children
# 1062. 1520019 -hasCategory-> automotive accessories
# 1063. 1520019 -hasBrand-> IKON MOTORSPORTS
# 1064. 1520019 -hasCharacteristic-> High Quality Nylon
# 1065. 1520019 -hasColor-> Black
# 1066. 1520019 -hasMeasurement-> Front Rear 4PCS Set
# 1067. 1520019 -isFor-> adults
# 1068. 1037852 -hasCategory-> supplements
# 1069. 1037852 -hasCharacteristic-> Vegetarian
# 1070. 1037852 -hasMeasurement-> 60 capsules
# 1071. 1037852 -hasBrand-> Purity Products
# 1072. 1037852 -hasCharacteristic-> 30 Day Supply
# 1073. 1037852 -hasCharacteristic-> contains Green Tea
# 1074. 1037852 -hasCharacteristic-> contains Curcumin
# 1075. 1037852 -hasCharacteristic-> contains Resveratrol
# 1076. 1037852 -hasCharacteristic-> FSSAI Importer Licence
# 1077. 1037852 -hasCharacteristic-> BCM-95 BioCurcumin
# 1078. 1037852 -hasCharacteristic-> Grape Seed extract
# 1079. 1037852 -hasCharacteristic-> Pine Bark extract
# 1080. 1037852 -hasCharacteristic-> Ellagic Acid
# 1081. 1037852 -hasCharacteristic-> Citrus Bioflavonoids
# 1082. 1037852 -isFor-> adults
# 1083. 1494815 -hasCategory-> men clothing
# 1084. 1494815 -hasCharacteristic-> Midweight
# 1085. 1494815 -hasCharacteristic-> Letter Decoration
# 1086. 1494815 -hasMeasurement-> Size 32
# 1087. 1494815 -hasBrand-> Sokotoo
# 1088. 1494815 -hasColor-> black
# 1089. 1494815 -isFor-> adults
# 1090. 1292422 -hasCategory-> men clothing
# 1091. 1292422 -hasBrand-> BEEVEE
# 1092. 1292422 -hasCharacteristic-> 100% Cotton
# 1093. 1292422 -hasCharacteristic-> Regular Fit
# 1094. 1292422 -hasCharacteristic-> Hand wash
# 1095. 1292422 -hasCharacteristic-> Drawstring Closure
# 1096. 1292422 -hasColor-> sand
# 1097. 1292422 -isFor-> adults
# 1098. 1618901 -hasCategory-> beauty
# 1099. 1618901 -hasBrand-> CIBBCCI
# 1100. 1618901 -hasCharacteristic-> Waterproof
# 1101. 1618901 -hasCharacteristic-> Ultra Pigmented
# 1102. 1618901 -hasColor-> Pink Mermaid Warm-toned
# 1103. 1618901 -hasMeasurement-> 9 Colors
# 1104. 1618901 -hasCharacteristic-> Matte
# 1105. 1618901 -hasCharacteristic-> Shimmer
# 1106. 1618901 -isFor-> adults
# 1107. 2150415 -hasCategory-> home decoration
# 1108. 2150415 -hasCategory-> bath mat
# 1109. 2150415 -hasBrand-> Zollyss
# ...
# 1491. 1782219 -hasBrand-> PnF
# 1492. 1782219 -hasCharacteristic-> Light weight
# 1493. 1782219 -hasCharacteristic-> Water Splash Proof
# 1494. 1782219 -hasCharacteristic-> Easy To Clean
# 1495. 1782219 -hasCharacteristic-> Ready to Hang
# 1496. 1782219 -hasColor-> Multicolour
# 1497. 1782219 -isFor-> adults
# 1498. 2853470 -hasCategory-> mobile accessories
# 1499. 2853470 -hasBrand-> Bridion
# 1500. 2853470 -hasCharacteristic-> Hard Plastic
# 1501. 2853470 -hasCharacteristic-> Designer
# 1502. 2853470 -hasColor-> Multi Colour
# 1503. 2853470 -isFor-> adults
# 1504. 1431607 -hasCategory-> footwear
# 1505. 1431607 -hasCharacteristic-> Air Mesh Upper
# 1506. 1431607 -hasCharacteristic-> Breathability
# 1507. 1431607 -hasCharacteristic-> Comfort
# 1508. 1431607 -hasCharacteristic-> Sr Touch
# 1509. 1431607 -hasCharacteristic-> Shock Absorbing Mid-Sole
# 1510. 1431607 -hasCharacteristic-> Advanced Cushioning Material
# 1511. 1431607 -hasCharacteristic-> Lightweight
# 1512. 1431607 -hasMeasurement-> 10 ounces
# 1513. 1431607 -hasColor-> White/Black
# 1514. 1431607 -isFor-> adults
# 1515. 2272336 -hasCategory-> phone cases & covers
# 1516. 2272336 -hasBrand-> UbrosNetwork
# 1517. 2272336 -hasCharacteristic-> Shockproof
# 1518. 2272336 -hasCharacteristic-> 360 Protection
# 1519. 2272336 -hasCharacteristic-> Wallet Style
# 1520. 2272336 -hasCharacteristic-> Magnetic Closure
# 1521. 2272336 -hasColor-> black
# 1522. 2272336 -isFor-> adults
# 1523. 1843659 -hasCategory-> mobile accessories
# 1524. 1843659 -hasBrand-> Pikkme
# 1525. 1843659 -hasCharacteristic-> Designer Printed
# 1526. 1843659 -hasCharacteristic-> Hard
# 1527. 1843659 -hasCharacteristic-> Matte Finish
# 1528. 1843659 -hasCharacteristic-> High Quality Poly-carbonate Material
# 1529. 1843659 -hasCharacteristic-> Non-Yellowing
# 1530. 1843659 -hasCharacteristic-> Korean-Ink Sublimation Printing
# 1531. 1843659 -hasCharacteristic-> Lifetime Print Warranty
# 1532. 1843659 -hasCharacteristic-> Precision Cut-Outs
# 1533. 1843659 -hasColor-> white
# 1534. 1843659 -isFor-> adults
# 1535. 2552742 -hasCategory-> home decoration
# 1536. 2552742 -hasCategory-> wall art
# 1537. 2552742 -hasBrand-> NATVVA
# 1538. 2552742 -hasCharacteristic-> with frame
# 1539. 2552742 -hasCharacteristic-> handmade
# 1540. 2552742 -hasCharacteristic-> High Quality Glossy Canvas
# 1541. 2552742 -isFor-> adults
# 1542. 1422789 -hasCategory-> wood lathe turning tools
# 1543. 1422789 -hasBrand-> OSCARBIDE
# 1544. 1422789 -hasCharacteristic-> solid tungsten carbide
# 1545. 1422789 -hasCharacteristic-> 30° cutting angle
# 1546. 1422789 -hasMeasurement-> 18mm diameter
# 1547. 1422789 -hasMeasurement-> 3mm thickness
# 1548. 1422789 -isFor-> adults
# 1549. 349848 -hasCategory-> books
# 1550. 999198 -hasCategory-> computer accessories
# 1551. 999198 -hasMeasurement-> 15.6 LED BOTTOM LEFT WXGA HD
# 1552. 999198 -hasBrand-> Dell
# 1553. 999198 -isFor-> adults
# 1554. 2988079 -hasCategory-> men clothing
# 1555. 2988079 -hasCharacteristic-> Rubber
# 1556. 2988079 -hasCharacteristic-> Cotton
# 1557. 2988079 -hasCharacteristic-> Ultra-breathable
# 1558. 2988079 -hasBrand-> Veer ji Collection
# 1559. 2988079 -hasColor-> Multi colour
# 1560. 2988079 -isFor-> adults
# 1561. 1833730 -hasCategory-> footwear
# 1562. 1833730 -hasBrand-> Khadims
# 1563. 1833730 -hasCharacteristic-> Synthetic Upper Material
# 1564. 1833730 -hasCharacteristic-> Airmax Sole Material
# 1565. 1833730 -hasCharacteristic-> Slip-on Closure
# 1566. 1833730 -hasCharacteristic-> Closed Toe Style
# 1567. 1833730 -hasColor-> black
# 1568. 1833730 -hasMeasurement-> UK 9
# 1569. 1833730 -isFor-> adults
# 1570. 2228281 -hasCategory-> healthcare supply
# 1571. 2228281 -hasCharacteristic-> Large Print
# 1572. 2228281 -isFor-> adults
# 1573. 2548596 -hasCategory-> calendar
# 1574. 2548596 -hasCharacteristic-> Baseball Schedule Included
# 1575. 2548596 -hasCharacteristic-> High quality vibrant photos
# 1576. 2548596 -hasCharacteristic-> Made in the USA
# 1577. 2548596 -hasMeasurement-> 12" x 24" open
# 1578. 2548596 -hasBrand-> Red Sock
# 1579. 2548596 -isFor-> adults
# 1580. 1278281 -hasCategory-> home decoration
# 1581. 1278281 -hasBrand-> Amy Vangsgard
# 1582. 1278281 -hasCharacteristic-> Contemporary
# 1583. 1278281 -hasMeasurement-> 16x20-Inch
# 1584. 1278281 -hasColor-> white
# 1585. 1278281 -hasColor-> black
# 1586. 1278281 -isFor-> adults
# 1587. 448602 -hasCategory-> book
# 1588. 448602 -hasCategory-> literature
# 1589. 1673887 -hasCategory-> fashion accessories
# 1590. 1673887 -hasBrand-> Vibedration
# 1591. 1673887 -hasCharacteristic-> Adjustable Strap
# 1592. 1673887 -hasMeasurement-> 25" to 49" waist size
# 1593. 1673887 -hasCharacteristic-> 3-Pockets
# 1594. 1673887 -hasCharacteristic-> Water-Resistant
# 1595. 1673887 -hasColor-> Plaid Out
# 1596. 1673887 -isFor-> adults
# 1597. 1490421 -hasCategory-> accessories
# 1598. 1490421 -hasBrand-> APHISON
# 1599. 1490421 -hasCharacteristic-> Card Holder
# 1600. 1490421 -hasCharacteristic-> Zipper Purse
# 1601. 1490421 -hasCharacteristic-> Phone Clutch
# 1602. 1490421 -hasCharacteristic-> Wristlet
# 1603. 1490421 -hasCharacteristic-> RFID Blocking
# 1604. 1490421 -hasMeasurement-> 7.9 x 1.2 x 4.4 inches
# 1605. 1490421 -isFor-> adults
# 1606. 883967 -hasCategory-> personal care
# 1607. 883967 -hasBrand-> Beauty Without Cruelty
# 1608. 883967 -isFor-> adults
# 1609. 1659260 -hasCategory-> snow sports equipment
# 1610. 1659260 -hasBrand-> BERN
# 1611. 1659260 -hasCharacteristic-> Lightweight
# 1612. 1659260 -hasCharacteristic-> Durable
# 1613. 1659260 -hasCharacteristic-> Replaceable liners
# 1614. 1659260 -hasCharacteristic-> EAR technology
# 1615. 1659260 -hasCharacteristic-> Aluminum Shields
# 1616. 1659260 -hasColor-> Matte Slate Green
# 1617. 1659260 -hasMeasurement-> Small
# 1618. 929932 -hasCategory-> musical instruments
# 1619. 929932 -hasMeasurement-> 16 -1/4"L x .585"D
# 1620. 929932 -hasBrand-> Vic Firth
# 1621. 929932 -isFor-> adults
# 1622. 2653437 -hasCategory-> mobile accessories
# 1623. 2653437 -hasBrand-> Generic
# 1624. 2653437 -hasCharacteristic-> Hard Plastic
# 1625. 2653437 -hasCharacteristic-> Designer
# 1626. 2653437 -hasCharacteristic-> Tough
# 1627. 2653437 -hasCharacteristic-> Shock Absorbent
# 1628. 2653437 -hasColor-> Multi Colour
# 1629. 2653437 -isFor-> adults
# 1630. 2965076 -hasCategory-> pet supplies
# 1631. 2965076 -hasCharacteristic-> Universal Stretchable
# 1632. 2965076 -hasCharacteristic-> 3 Layers
# 1633. 2965076 -hasCharacteristic-> Auto Safety Mesh Organizer
# 1634. 2965076 -hasCharacteristic-> Easy to install
# 1635. 2965076 -hasBrand-> MIZZEO
# 1636. 2965076 -hasMeasurement-> 11.7in x 11.7in
# 1637. 2965076 -isFor-> adults
# 1638. 2934016 -hasCategory-> footwear
# 1639. 2934016 -hasBrand-> Columbus
# 1640. 2934016 -hasCharacteristic-> breathability
# 1641. 2934016 -hasCharacteristic-> Comfortable
# 1642. 2934016 -hasCharacteristic-> Ultra-soft insole
# 1643. 2934016 -hasColor-> black
# 1644. 2934016 -hasMeasurement-> UK/India-8
# 1645. 2934016 -isFor-> adults
# 1646. 2657579 -hasCategory-> men's footwear
# 1647. 2657579 -hasBrand-> EZOK
# 1648. 2657579 -hasCharacteristic-> light weight
# 1649. 2657579 -hasCharacteristic-> durable
# 1650. 2657579 -hasCharacteristic-> comfortable
# 1651. 2657579 -hasCharacteristic-> water resistance
# 1652. 2657579 -hasMeasurement-> 9 UK
# 1653. 2657579 -hasColor-> tan
# 1654. 2657579 -isFor-> adults
# 1655. 2842292 -hasCategory-> mobile accessories
# 1656. 2842292 -hasBrand-> Cellryte
# 1657. 2842292 -hasCharacteristic-> 3D
# 1658. 2842292 -hasCharacteristic-> 9H Hardness
# 1659. 2842292 -hasCharacteristic-> Bubble Free
# 1660. 2842292 -hasCharacteristic-> Easy Installation
# 1661. 2842292 -hasCharacteristic-> Anti-scratch
# 1662. 2842292 -hasCharacteristic-> HD Clarity
# 1663. 2842292 -hasCharacteristic-> 100% transparency
# 1664. 2842292 -hasCharacteristic-> oleophobic anti-smudge coating
# 1665. 2842292 -hasCharacteristic-> Scratch Resistant
# 1666. 2842292 -hasCharacteristic-> Anti-Fingerprint
# 1667. 2842292 -hasCharacteristic-> Touch Sensitive
# 1668. 2842292 -hasCharacteristic-> Anti-Glare
# 1669. 2842292 -hasCharacteristic-> Gloss Finish
# 1670. 2842292 -hasColor-> black
# 1671. 2842292 -isFor-> adults
# 1672. 2243426 -hasCategory-> home decoration
# 1673. 2243426 -hasCharacteristic-> Rod Pocket Blackout
# 1674. 2243426 -hasCharacteristic-> Room Darkening
# 1675. 2243426 -hasMeasurement-> 29 x 63 Inch
# 1676. 2243426 -hasColor-> pink
# 1677. 2243426 -isFor-> children
# 1678. 2666747 -hasCategory-> women clothing
# 1679. 2666747 -hasCategory-> lingerie
# 1680. 2666747 -hasCharacteristic-> Lace
# 1681. 2666747 -hasCharacteristic-> Babydoll
# 1682. 2666747 -hasCharacteristic-> Sleepwear
# 1683. 2666747 -hasCharacteristic-> Boudoir Outfits
# 1684. 2666747 -hasCharacteristic-> Plus Size
# 1685. 2666747 -isFor-> adults
# 1686. 2656446 -hasCategory-> children clothing
# 1687. 2656446 -hasBrand-> TONYBOY
# 1688. 2656446 -hasCharacteristic-> Regular Fit
# 1689. 2656446 -hasCharacteristic-> Full Sleeve
# 1690. 2656446 -hasCharacteristic-> Regular Collar
# 1691. 2656446 -hasColor-> Green
# 1692. 2656446 -hasColor-> Fluo Orange
# 1693. 2656446 -isFor-> children
# 1694. 1955596 -hasCategory-> home storage
# 1695. 1955596 -hasCharacteristic-> Stackable
# 1696. 1955596 -hasCharacteristic-> Nested
# 1697. 1955596 -hasCharacteristic-> Cutout Handles
# 1698. 1955596 -hasCharacteristic-> Metal Plated Edges
# 1699. 1955596 -hasMeasurement-> Large: 13.00” x 9.84” x 5.12”
# 1700. 1955596 -hasMeasurement-> Small: 7.87” x 5.91” x 4.33”
# 1701. 1955596 -hasBrand-> Home Zone Living
# 1702. 1955596 -isFor-> adults
# 1703. 1818763 -hasCategory-> women clothing
# 1704. 1818763 -hasCharacteristic-> Floral
# 1705. 1818763 -hasCharacteristic-> Sleeveless
# 1706. 1818763 -hasCharacteristic-> Tank Dress
# 1707. 1818763 -hasCharacteristic-> Bohemia
# 1708. 1818763 -hasCharacteristic-> Deep V Neck
# 1709. 1818763 -hasCharacteristic-> Tassels
# 1710. 1818763 -hasCharacteristic-> Beach Long Dress
# 1711. 1818763 -hasBrand-> GREFER
# 1712. 1818763 -isFor-> adults
# 1713. 548246 -hasCategory-> book
# 1714. 973904 -hasCategory-> electronic components
# 1715. 973904 -hasMeasurement-> 500 V 25 A 410 W 270 R
# 1716. 973904 -hasBrand-> Fixapart
# 1717. 973904 -hasCharacteristic-> Irfp460-Mbr
# 1718. 2088100 -hasCategory-> home decoration
# 1719. 2088100 -hasBrand-> Liltime
# 1720. 2088100 -hasCharacteristic-> Handmade
# 1721. 2088100 -hasMeasurement-> 34.5*11.8 IN
# 1722. 2088100 -hasCharacteristic-> Natural cotton rope
# 1723. 2088100 -hasCharacteristic-> Wood beads
# 1724. 2088100 -hasCharacteristic-> Wood dowel
# 1725. 2088100 -isFor-> adults
# 1726. 949098 -hasCategory-> art supplies
# 1727. 949098 -hasCharacteristic-> High Pigment
# 1728. 949098 -hasCharacteristic-> Excellent Coverage
# 1729. 949098 -hasCharacteristic-> Water Resistant
# 1730. 949098 -hasMeasurement-> 500 ml
# 1731. 949098 -hasColor-> Rose Madder
# 1732. 949098 -hasBrand-> Soho Urban Artist
# 1733. 949098 -isFor-> adults
# 1734. 2637249 -hasCategory-> craft supplies
# 1735. 2637249 -hasMeasurement-> 8 mm
# 1736. 2637249 -hasBrand-> The Design Cart
# 1737. 2637249 -hasColor-> light purple
# 1738. 2637249 -hasCharacteristic-> glossy finish
# 1739. 2637249 -isFor-> adults
# 1740. 1243984 -hasCategory-> footwear
# 1741. 1243984 -hasBrand-> crocs
# 1742. 1243984 -hasColor-> navy
# 1743. 1243984 -hasMeasurement-> 5 UK (M6)
# 1744. 1243984 -hasCharacteristic-> Synthetic
# 1745. 1243984 -hasCharacteristic-> Slip On
# 1746. 1243984 -hasCharacteristic-> Round Toe
# 1747. 1243984 -hasCharacteristic-> 90 days warranty
# 1748. 1243984 -isFor-> adults
# 1749. 1050497 -hasCategory-> footwear
# 1750. 1050497 -hasBrand-> Nike
# 1751. 1050497 -hasColor-> White Wolf Grey
# 1752. 1050497 -hasMeasurement-> UK 9 US 10 EU 44
# 1753. 1050497 -isFor-> adults
# 1754. 1789190 -hasCategory-> home decoration
# 1755. 1789190 -hasBrand-> Foreside Home and Garden
# 1756. 1789190 -hasMeasurement-> 39.5 x 2.5 x 30"H
# 1757. 1789190 -hasColor-> multi
# 1758. 2837866 -hasCategory-> archery equipment
# 1759. 2837866 -hasBrand-> Calandis
# 1760. 2837866 -hasCharacteristic-> Adjustable shoulder strap
# 1761. 2837866 -hasCharacteristic-> Large carrying capacity
# 1762. 2837866 -hasMeasurement-> 59x9 cm/23.2x3.5 inch
# 1763. 2837866 -hasColor-> Camouflage
# 1764. 2837866 -isFor-> adults
# 1765. 965437 -hasCategory-> vehicle accessories
# 1766. 965437 -hasBrand-> MOR/ryde
# 1767. 965437 -hasCharacteristic-> Fully assembled
# 1768. 965437 -hasCharacteristic-> Finished carpeted flooring
# 1769. 965437 -hasCharacteristic-> Ready to install
# 1770. 965437 -hasCharacteristic-> 60% extension
# 1771. 965437 -hasMeasurement-> CTG60-2060W
# 1772. 20255 -hasCategory-> book
# 1773. 20255 -hasCategory-> academic literature
# 1774. 20255 -hasBrand-> Oxford Monographs on Criminal Law and Justice
# 1775. 20255 -isFor-> adults
# 1776. 1483279 -hasCategory-> women clothing
# 1777. 1483279 -hasBrand-> ABOF
# 1778. 1483279 -hasCharacteristic-> machine washable
# 1779. 1483279 -hasCharacteristic-> hand washable
# 1780. 1483279 -hasCharacteristic-> round neck v-slit
# 1781. 1483279 -hasCharacteristic-> extended shoulder
# 1782. 1483279 -hasCharacteristic-> t-shirt look
# 1783. 1483279 -hasCharacteristic-> midi length
# 1784. 1483279 -hasCharacteristic-> printed
# 1785. 1483279 -hasCharacteristic-> light weight
# 1786. 1483279 -hasMeasurement-> Chest size XS= 34 inches
# 1787. 1483279 -hasMeasurement-> Chest size S= 36 inches
# 1788. 1483279 -hasMeasurement-> Chest size M= 38 inches
# 1789. 1483279 -hasMeasurement-> Chest size L= 40 inches
# 1790. 1483279 -hasMeasurement-> Chest size XL= 42 inches
# 1791. 1483279 -hasMeasurement-> Chest size XXL= 44 inches
# 1792. 1483279 -hasColor-> blue
# 1793. 1483279 -hasMaterial-> 100% Polyester
# 1794. 1483279 -isFor-> adults
# 1795. 1213829 -hasCategory-> window treatment accessories
# 1796. 1213829 -hasBrand-> Amazing Drapery Hardware
# 1797. 1213829 -hasMeasurement-> 3 cm long, 2 cm wide
# 1798. 1213829 -hasCharacteristic-> real wood
# 1799. 1213829 -hasColor-> Bone/Alabaster/Neutral
# 1800. 1213829 -isFor-> adults
# 1801. 2647404 -hasCategory-> mobile accessories
# 1802. 2647404 -hasBrand-> Alve
# 1803. 2647404 -hasCharacteristic-> 3D designer
# 1804. 2647404 -hasCharacteristic-> Durable
# 1805. 2647404 -hasCharacteristic-> light weight
# 1806. 2647404 -hasCharacteristic-> High quality
# 1807. 2647404 -hasCharacteristic-> polycarbonate
# 1808. 2647404 -hasCharacteristic-> hard back case
# 1809. 2647404 -hasCharacteristic-> complete protection
# 1810. 2647404 -hasCharacteristic-> 3D sublimation imaging technology
# 1811. 2647404 -hasCharacteristic-> high resolution designs
# 1812. 1870691 -hasCategory-> phone accessories
# 1813. 1870691 -hasBrand-> CoKo
# 1814. 1870691 -hasCharacteristic-> Camera Lens Protection
# 1815. 1870691 -hasCharacteristic-> Shockproof
# 1816. 1870691 -hasCharacteristic-> Slim
# 1817. 1870691 -hasCharacteristic-> Anti-dust
# 1818. 1870691 -hasCharacteristic-> Scratch-free
# 1819. 1870691 -hasCharacteristic-> Easy to Install
# 1820. 1870691 -hasColor-> transparent
# 1821. 1870691 -isFor-> adults
# 1822. 1730401 -hasCategory-> accessories
# 1823. 1730401 -hasBrand-> Zazzy Bandz
# 1824. 1730401 -hasCharacteristic-> Fits Like Sunglasses
# 1825. 1730401 -hasCharacteristic-> Volume and Style without the Headache
# 1826. 1730401 -hasCharacteristic-> Lightweight
# 1827. 1730401 -hasCharacteristic-> Perfect for normal to high volume hair
# 1828. 1730401 -hasCharacteristic-> Unsuitable for thin hair and/or small heads
# 1829. 1730401 -hasColor-> Silver
# 1830. 1730401 -isFor-> adults
# 1831. 2013780 -hasCategory-> home decoration
# 1832. 2013780 -hasMeasurement-> 18x12x1.5 inch
# 1833. 2013780 -hasBrand-> Looife
# 1834. 2013780 -hasCharacteristic-> Ready to Hang
# 1835. 2013780 -hasCharacteristic-> Giclee Printing
# 1836. 2013780 -hasCharacteristic-> Gallery Wrapped
# 1837. 2013780 -hasColor-> Red
# 1838. 2013780 -isFor-> adults
# 1839. 1152896 -hasCategory-> book
# 1840. 745816 -hasCategory-> books
# 1841. 745816 -isFor-> adults
# 1842. 18716 -hasCategory-> book
# 1843. 18716 -hasBrand-> Bhagwati, Jagdish
# 1844. 18716 -hasCharacteristic-> Hardcover
# 1845. 18716 -hasCharacteristic-> Reading Comprehension Boosters
# 1846. 18716 -isFor-> adults
# 1847. 2649663 -hasCategory-> mobile accessories
# 1848. 2649663 -hasBrand-> OYESTUFF
# 1849. 2649663 -hasCharacteristic-> Reliable Protection
# 1850. 2649663 -hasCharacteristic-> Durable
# 1851. 2649663 -hasCharacteristic-> Access to Ports
# 1852. 2649663 -hasColor-> Multi-Coloured
# 1853. 2649663 -isFor-> adults

# %% [markdown]
# Querying the database
#
# Creating vector indexes
#
# In order to efficiently search our database for terms closely related to user queries, we need to use embeddings. To do this, we will create vector indexes on each type of property.
#
# We will be using the OpenAIEmbeddings Langchain utility. It's important to note that Langchain adds a pre-processing step, so the embeddings will slightly differ from those generated directly with the OpenAI embeddings API.

# %%
# !ollama pull nomic-embed-text
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 970aa74c0a90: 100% ▕██████████████████▏ 274 MB
# pulling c71d239df917: 100% ▕██████████████████▏  11 KB
# pulling ce4a164fc046: 100% ▕██████████████████▏   17 B
# pulling 31df23ea7daa: 100% ▕██████████████████▏  420 B
# verifying sha256 digest
# writing manifest
# success

# %%
from langchain.vectorstores.neo4j_vector import Neo4jVector
from langchain_ollama import OllamaEmbeddings
embeddings_model = "nomic-embed-text"
embeddings = OllamaEmbeddings(
    model=embeddings_model,
)

# %%
vector_index = Neo4jVector.from_existing_graph(
    embeddings,
    url=url,
    username=username,
    password=password,
    index_name='products',
    node_label="Product",
    text_node_properties=['name', 'title'],
    embedding_node_property='embedding',
)

# result = vector_index.similarity_search("Slovenia", k=1)

print(df['entity_type'].unique())
# Out:
# ['category' 'brand' 'characteristic' 'measurement' 'color' 'age_group'
#  'material']

# %%
def embed_entities(entity_type):
    vector_index = Neo4jVector.from_existing_graph(
        embeddings,
        url=url,
        username=username,
        password=password,
        index_name=entity_type,
        node_label=entity_type,
        text_node_properties=['value'],
        embedding_node_property='embedding',
    )
    
entities_list = df['entity_type'].unique()

for t in entities_list:
    print(t)
    embed_entities(t)
# Out:
# category
# brand
# characteristic
# measurement
# color
# age_group
# material

# %% [markdown]
# Querying the database directly
#
# Using GraphCypherQAChain, we can generate queries against the database using Natural Language.

# %%
# !ollama pull gpt-oss:20b-cloud
# !pip3 install -U langchain-ollama
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling cf2ed067e945: 100% ▕██████████████████▏  381 B
# verifying sha256 digest
# writing manifest
# success
# Requirement already satisfied: langchain-ollama in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (0.3.8)
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain-ollama)
#   Using cached langchain_core-1.0.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ollama<1.0.0,>=0.6.0 (from langchain-ollama)
#   Using cached ollama-0.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.29)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.11.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.10.16)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.25.0)
# Requirement already satisfied: anyio in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.9.0)
# Requirement already satisfied: certifi in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.8)
# Requirement already satisfied: idna in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sushi\anaconda3\envs\llms\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sushi\appdata\roaming\python\python311\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.3.1)
# Downloading langchain_ollama-1.0.0-py3-none-any.whl (29 kB)
# Using cached langchain_core-1.0.0-py3-none-any.whl (467 kB)
# Using cached ollama-0.6.0-py3-none-any.whl (14 kB)
# Installing collected packages: ollama, langchain-core, langchain-ollama
#
#   Attempting uninstall: ollama
#
#     Found existing installation: ollama 0.5.4
#
#     Uninstalling ollama-0.5.4:
#
#       Successfully uninstalled ollama-0.5.4
#
#   Attempting uninstall: langchain-core
#
#     Found existing installation: langchain-core 0.3.79
#
#    ------------- -------------------------- 1/3 [langchain-core]
#     Uninstalling langchain-core-0.3.79:
#    ------------- -------------------------- 1/3 [langchain-core]
#       Successfully uninstalled langchain-core-0.3.79
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-core]
#   Attempting uninstall: langchain-ollama
#    ------------- -------------------------- 1/3 [langchain-core]
#     Found existing installation: langchain-ollama 0.3.8
#    ------------- -------------------------- 1/3 [langchain-core]
#     Uninstalling langchain-ollama-0.3.8:
#    ------------- -------------------------- 1/3 [langchain-core]
#       Successfully uninstalled langchain-ollama-0.3.8
#    ------------- -------------------------- 1/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-ollama]
#    ---------------------------------------- 3/3 [langchain-ollama]
#
# Successfully installed langchain-core-1.0.0 langchain-ollama-1.0.0 ollama-0.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.0 which is incompatible.
# langchain-anthropic 0.3.20 requires langchain-core<1.0.0,>=0.3.76, but you have langchain-core 1.0.0 which is incompatible.
# langchain-neo4j 0.5.0 requires langchain-core<0.4.0,>=0.3.39, but you have langchain-core 1.0.0 which is incompatible.
# langchain-openai 0.3.33 requires langchain-core<1.0.0,>=0.3.76, but you have langchain-core 1.0.0 which is incompatible.

# %%
graph.refresh_schema()

# %%
print(graph.schema)
# Out:
# Node properties:
# Product {id: INTEGER, name: STRING, title: STRING, bullet_points: STRING, size: FLOAT, embedding: LIST}
# category {value: STRING, embedding: LIST}
# brand {value: STRING, embedding: LIST}
# characteristic {value: STRING, embedding: LIST}
# measurement {value: STRING, embedding: LIST}
# color {value: STRING, embedding: LIST}
# age_group {value: STRING, embedding: LIST}
# material {value: STRING, embedding: LIST}
# Relationship properties:
#
# The relationships:
# (:Product)-[:hasCategory]->(:category)
# (:Product)-[:hasBrand]->(:brand)
# (:Product)-[:hasCharacteristic]->(:characteristic)
# (:Product)-[:hasMeasurement]->(:measurement)
# (:Product)-[:hasColor]->(:color)
# (:Product)-[:isFor]->(:age_group)
# (:Product)-[:hasMaterial]->(:characteristic)
# (:Product)-[:hasMaterial]->(:material)

# %%
enhanced_graph = Neo4jGraph(
    url=url, 
    username=username, 
    password=password,
    enhanced_schema=True,
)
print(enhanced_graph.schema)
# Out:
# Node properties:
# - **Product**
#   - `id`: INTEGER Min: 18716, Max: 2998633
#   - `name`: STRING Example: "Blackout Curtain"
#   - `title`: STRING Example: "ArtzFolio Tulip Flowers Blackout Curtain for Door,"
#   - `bullet_points`: STRING Example: "[LUXURIOUS & APPEALING: Beautiful custom-made curt"
#   - `size`: FLOAT Min: 10.0, Max: 10800.0
# - **category**
#   - `value`: STRING Example: "home decoration"
# - **brand**
#   - `value`: STRING Example: "ArtzFolio"
# - **characteristic**
#   - `value`: STRING Example: "Eyelets"
# - **measurement**
#   - `value`: STRING Example: "Width 4.5 feet (54 inch) Height 5 feet (60 inch)"
# - **color**
#   - `value`: STRING Example: "Multicolour"
# - **age_group**
#   - `value`: STRING Available options: ['adults', 'children']
# - **material**
#   - `value`: STRING Available options: ['100% Polyester']
# Relationship properties:
#
# The relationships:
# (:Product)-[:hasCategory]->(:category)
# (:Product)-[:hasBrand]->(:brand)
# (:Product)-[:hasCharacteristic]->(:characteristic)
# (:Product)-[:hasMeasurement]->(:measurement)
# (:Product)-[:hasColor]->(:color)
# (:Product)-[:isFor]->(:age_group)
# (:Product)-[:hasMaterial]->(:characteristic)
# (:Product)-[:hasMaterial]->(:material)

# %%
from langchain_neo4j import GraphCypherQAChain
from langchain.chat_models import ChatOllama

chain = GraphCypherQAChain.from_llm(
    ChatOllama(
        model="gpt-oss:20b-cloud",
        temperature=0
    # other params ...
    ), 
    graph=graph,
    verbose=True,
    top_k=2,
    allow_dangerous_requests=True,
)

await chain.acall("curtains")
# Out:
# 0

# %%
chain.run("""
Help me find curtains
""")
# Out:
# > Entering new GraphCypherQAChain chain...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 chain.run("""
#       2 Help me find curtains
#       3 """)
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_core\_api\deprecation.py:193, in warning_emitting_wrapper(*args, **kwargs)
#     191 """Same as warning_emitting_wrapper, but for async functions."""
#     192 nonlocal warned
# --> 193 if not warned and not is_caller_internal():
#     194     warned = True
#     195     emit_warning()
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
#     631 if kwargs and not args:
#     632     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     633         _output_key
#     634     ]
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_core\_api\deprecation.py:193, in warning_emitting_wrapper(*args, **kwargs)
#     191 """Same as warning_emitting_wrapper, but for async functions."""
#     192 nonlocal warned
# --> 193 if not warned and not is_caller_internal():
#     194     warned = True
#     195     emit_warning()
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:410, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     378 """Execute the chain.
#     379
#     380 Args:
#    (...)    401         `Chain.output_keys`.
#     402 """
#     403 config = {
#     404     "callbacks": callbacks,
#     405     "tags": tags,
#     406     "metadata": metadata,
#     407     "run_name": run_name,
#     408 }
# --> 410 return self.invoke(
#     411     inputs,
#     412     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     413     return_only_outputs=return_only_outputs,
#     414     include_run_info=include_run_info,
#     415 )
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     162 try:
#     163     self._validate_inputs(inputs)
#     164     outputs = (
# --> 165         self._call(inputs, run_manager=run_manager)
#     166         if new_arg_supported
#     167         else self._call(inputs)
#     168     )
#     170     final_outputs: dict[str, Any] = self.prep_outputs(
#     171         inputs,
#     172         outputs,
#     173         return_only_outputs,
#     174     )
#     175 except BaseException as e:
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_neo4j\chains\graph_qa\cypher.py:335, in GraphCypherQAChain._call(self, inputs, run_manager)
#     331 args.update(inputs)
#     333 intermediate_steps: List = []
# --> 335 generated_cypher = self.cypher_generation_chain.invoke(
#     336     args, callbacks=callbacks
#     337 )
#     339 # Extract Cypher code if it is wrapped in backticks
#     340 generated_cypher = extract_cypher(generated_cypher)
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_core\runnables\base.py:3219, in invoke(self, input, config, **kwargs)
#    3195 inputs = step.batch(
#    3196     [
#    3197         inp
#    (...)   3213     **(kwargs if stepidx == 0 else {}),
#    3214 )
#    3215 # If an input failed, add it to the map
#    3216 failed_inputs_map.update(
#    3217     {
#    3218         i: inp
# -> 3219         for i, inp in zip(remaining_idxs, inputs, strict=False)
#    3220         if isinstance(inp, Exception)
#    3221     }
#    3222 )
#    3223 inputs = [inp for inp in inputs if not isinstance(inp, Exception)]
#    3224 # If all inputs have failed, stop processing
#
# ModuleNotFoundError: No module named 'langchain_core.beta'

# %% [markdown]
# Extracting entities from the prompt
#
# However, there is little added value here compared to just writing the Cypher queries ourselves, and it is prone to error.
#
# Indeed, asking an LLM to generate a Cypher query directly might result in the wrong parameters being used, whether it's the entity type or the relationship type, as is the case above.
#
# We will instead use LLMs to decide what to search for, and then generate the corresponding Cypher queries using templates.
#
# For this purpose, we will instruct our model to find relevant entities in the user prompt that can be used to query our database.

# %%
entity_types = {
    "product": "Item detailed type, for example 'high waist pants', 'outdoor plant pot', 'chef kitchen knife'",
    "category": "Item category, for example 'home decoration', 'women clothing', 'office supply'",
    "characteristic": "if present, item characteristics, for example 'waterproof', 'adhesive', 'easy to use'",
    "measurement": "if present, dimensions of the item", 
    "brand": "if present, brand of the item",
    "color": "if present, color of the item",
    "age_group": "target age group for the product, one of 'babies', 'children', 'teenagers', 'adults'. If suitable for multiple age groups, pick the oldest (latter in the list)."
}

relation_types = {
    "hasCategory": "item is of this category",
    "hasCharacteristic": "item has this characteristic",
    "hasMeasurement": "item is of this measurement",
    "hasBrand": "item is of this brand",
    "hasColor": "item is of this color", 
    "isFor": "item is for this age_group"
 }

entity_relationship_match = {
    "category": "hasCategory",
    "characteristic": "hasCharacteristic",
    "measurement": "hasMeasurement", 
    "brand": "hasBrand",
    "color": "hasColor",
    "age_group": "isFor"
}

# %%
system_prompt = f'''
    You are a helpful agent designed to fetch information from a graph database. 
    
    The graph database links products to the following entity types:
    {json.dumps(entity_types)}
    
    Each link has one of the following relationships:
    {json.dumps(relation_types)}

    Depending on the user prompt, determine if it possible to answer with the graph database.
        
    The graph database can match products with multiple relationships to several entities.
    
    Example user input:
    "Which blue clothing items are suitable for adults?"
    
    There are three relationships to analyse:
    1. The mention of the blue color means we will search for a color similar to "blue"
    2. The mention of the clothing items means we will search for a category similar to "clothing"
    3. The mention of adults means we will search for an age_group similar to "adults"
    
    
    Return a json object following the following rules:
    For each relationship to analyse, add a key value pair with the key being an exact match for one of the entity types provided, and the value being the value relevant to the user query.
    
    For the example provided, the expected output would be:
    {{
        "color": "blue",
        "category": "clothing",
        "age_group": "adults"
    }}
    
    If there are no relevant entities in the user prompt, return an empty json object.
'''

print(system_prompt)
# Out:
#     You are a helpful agent designed to fetch information from a graph database.
#
#     The graph database links products to the following entity types:
#     {"product": "Item detailed type, for example 'high waist pants', 'outdoor plant pot', 'chef kitchen knife'", "category": "Item category, for example 'home decoration', 'women clothing', 'office supply'", "characteristic": "if present, item characteristics, for example 'waterproof', 'adhesive', 'easy to use'", "measurement": "if present, dimensions of the item", "brand": "if present, brand of the item", "color": "if present, color of the item", "age_group": "target age group for the product, one of 'babies', 'children', 'teenagers', 'adults'. If suitable for multiple age groups, pick the oldest (latter in the list)."}
#
#     Each link has one of the following relationships:
#     {"hasCategory": "item is of this category", "hasCharacteristic": "item has this characteristic", "hasMeasurement": "item is of this measurement", "hasBrand": "item is of this brand", "hasColor": "item is of this color", "isFor": "item is for this age_group"}
#
#     Depending on the user prompt, determine if it possible to answer with the graph database.
#
#     The graph database can match products with multiple relationships to several entities.
#
#     Example user input:
#     "Which blue clothing items are suitable for adults?"
#
#     There are three relationships to analyse:
#     1. The mention of the blue color means we will search for a color similar to "blue"
#     2. The mention of the clothing items means we will search for a category similar to "clothing"
#     3. The mention of adults means we will search for an age_group similar to "adults"
#
#
#     Return a json object following the following rules:
#     For each relationship to analyse, add a key value pair with the key being an exact match for one of the entity types provided, and the value being the value relevant to the user query.
#
#     For the example provided, the expected output would be:
#     {
#         "color": "blue",
#         "category": "clothing",
#         "age_group": "adults"
#     }
#
#     If there are no relevant entities in the user prompt, return an empty json object.

# %%
from openai import OpenAI
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# Define the entities to look for
def define_query(prompt, model="gpt-oss:20b-cloud"):
    response = ollama.chat.completions.create(
        model=model,
        temperature=0,
        response_format= {
            "type": "json_object"
        },
    messages=[
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": prompt
        }
        ]
    )
    return response.choices[0].message.content

# %%
example_queries = [
    "Which pink items are suitable for children?",
    "Help me find gardening gear that is waterproof",
    "I'm looking for a bench with dimensions 100x50 for my living room"
]

for q in example_queries:
    print(f"Q: '{q}'\n{define_query(q)}\n")
# Out:
# Q: 'Which pink items are suitable for children?'
# {
#   "color": "pink",
#   "age_group": "children"
# }
#
# Q: 'Help me find gardening gear that is waterproof'
# {
#   "category": "gardening gear",
#   "characteristic": "waterproof"
# }
#
# Q: 'I'm looking for a bench with dimensions 100x50 for my living room'
# {
#   "product": "bench",
#   "measurement": "100x50"
# }

# %% [markdown]
# Generating queries
#
# Now that we know what to look for, we can generate the corresponding Cypher queries to query our database.
#
# However, the entities extracted might not be an exact match with the data we have, so we will use the GDS cosine similarity function to return products that have relationships with entities similar to what the user is asking.

# %%
def create_embedding(text):
    result = ollama.embeddings.create(model=embeddings_model, input=text)
    return result.data[0].embedding

# %%
# The threshold defines how closely related words should be. Adjust the threshold to return more or less results
def create_query(text, threshold=0.81):
    query_data = json.loads(text)
    # Creating embeddings
    embeddings_data = []
    for key, val in query_data.items():
        if key != 'product':
            embeddings_data.append(f"${key}Embedding AS {key}Embedding")
    query = "WITH " + ",\n".join(e for e in embeddings_data)
    # Matching products to each entity
    query += "\nMATCH (p:Product)\nMATCH "
    match_data = []
    for key, val in query_data.items():
        if key != 'product':
            relationship = entity_relationship_match[key]
            match_data.append(f"(p)-[:{relationship}]->({key}Var:{key})")
    query += ",\n".join(e for e in match_data)
    similarity_data = []
    for key, val in query_data.items():
        if key != 'product':
            similarity_data.append(f"gds.similarity.cosine({key}Var.embedding, ${key}Embedding) > {threshold}")
    query += "\nWHERE "
    query += " AND ".join(e for e in similarity_data)
    query += "\nRETURN p"
    return query

# %%
def query_graph(response):
    embeddingsParams = {}
    query = create_query(response)
    query_data = json.loads(response)
    for key, val in query_data.items():
        embeddingsParams[f"{key}Embedding"] = create_embedding(val)
    result = graph.query(query, params=embeddingsParams)
    return result

# %%
example_response = '''{
    "category": "clothes",
    "color": "blue",
    "age_group": "adults"
}'''

result = query_graph(example_response)

print(len(result))
# Out:
# 0

# %%
# Result
print(f"Found {len(result)} matching product(s):\n")
for r in result:
    print(f"{r['p']['name']} ({r['p']['id']})")
# Out:
# Found 0 matching product(s):

# %% [markdown]
# Finding similar items
#
# We can then leverage the graph db to find similar products based on common characteristics.
#
# This is where the use of a graph db really comes into play.
#
# For example, we can look for products that are the same category and have another characteristic in common, or find products that have relationships to the same entities.
#
# This criteria is arbitrary and completely depends on what is the most relevant in relation to your use case.

# %%
# Adjust the relationships_threshold to return products that have more or less relationships in common
def query_similar_items(product_id, relationships_threshold = 3):
    
    similar_items = []
        
    # Fetching items in the same category with at least 1 other entity in common
    query_category = '''
            MATCH (p:Product {id: $product_id})-[:hasCategory]->(c:category)
            MATCH (p)-->(entity)
            WHERE NOT entity:category
            MATCH (n:Product)-[:hasCategory]->(c)
            MATCH (n)-->(commonEntity)
            WHERE commonEntity = entity AND p.id <> n.id
            RETURN DISTINCT n;
        '''
    

    result_category = graph.query(query_category, params={"product_id": int(product_id)})
    #print(f"{len(result_category)} similar items of the same category were found.")
          
    # Fetching items with at least n (= relationships_threshold) entities in common
    query_common_entities = '''
        MATCH (p:Product {id: $product_id})-->(entity),
            (n:Product)-->(entity)
            WHERE p.id <> n.id
            WITH n, COUNT(DISTINCT entity) AS commonEntities
            WHERE commonEntities >= $threshold
            RETURN n;
        '''
    result_common_entities = graph.query(query_common_entities, params={"product_id": int(product_id), "threshold": relationships_threshold})
    #print(f"{len(result_common_entities)} items with at least {relationships_threshold} things in common were found.")

    for i in result_category:
        similar_items.append({
            "id": i['n']['id'],
            "name": i['n']['name']
        })
            
    for i in result_common_entities:
        result_id = i['n']['id']
        if not any(item['id'] == result_id for item in similar_items):
            similar_items.append({
                "id": result_id,
                "name": i['n']['name']
            })
    return similar_items

# %%
product_ids = ['1519827', '2763742']

for product_id in product_ids:
    print(f"Similar items for product #{product_id}:\n")
    result = query_similar_items(product_id)
    print("\n")
    for r in result:
        print(f"{r['name']} ({r['id']})")
    print("\n\n")
# Out:
# Similar items for product #1519827:
#
#
#
# Womens Cotton Ankle Length Leggings (1594019)
# A Line Open Back Satin Prom Dress (1955999)
# Turtleneck Oversized Sweaters (2535064)
# Womens Satin Semi-Stitched Lehenga Choli (2763742)
# Womens Drawstring Harem Pants (1233616)
# Underwire Bra (1325580)
# Chiffon printed dupatta (2919319)
# Womens Lightly Padded Non-Wired Printed T-Shirt Bra (1954205)
# Glossies Thong (941830)
# Sun Uv Protection Driving Gloves (1844637)
# Dhoti Pants (2293307)
# Womens Maroon Round Neck Full Sleeves Gathered Peplum Top (1256928)
# V-Neck Long Jumpsuit (2838428)
# Alpine Faux Suede Knit Pencil Skirt (1372443)
# Lingerie for Women for Sex Naughty (2666747)
# Maxi Dresses (1818763)
# Womens Shift Knee-Long Dress (1483279)
#
#
#
# Similar items for product #2763742:
#
#
#
# Womens Cotton Ankle Length Leggings (1594019)
# A Line Open Back Satin Prom Dress (1955999)
# Turtleneck Oversized Sweaters (2535064)
# Plain V Neck Half Sleeves T Shirt (1519827)
# Womens Drawstring Harem Pants (1233616)
# Underwire Bra (1325580)
# Chiffon printed dupatta (2919319)
# Womens Lightly Padded Non-Wired Printed T-Shirt Bra (1954205)
# Glossies Thong (941830)
# Sun Uv Protection Driving Gloves (1844637)
# Dhoti Pants (2293307)
# Womens Maroon Round Neck Full Sleeves Gathered Peplum Top (1256928)
# V-Neck Long Jumpsuit (2838428)
# Alpine Faux Suede Knit Pencil Skirt (1372443)
# Lingerie for Women for Sex Naughty (2666747)
# Maxi Dresses (1818763)
# Womens Shift Knee-Long Dress (1483279)

# %% [markdown]
# Final result
#
# Now that we have all the pieces working, we will stitch everything together.
#
# We can also add a fallback option to do a product name/title similarity search if we can't find relevant entities in the user prompt.
#
# We will explore 2 options, one with a Langchain agent for a conversational experience, and one that is more deterministic based on code only.
#
# Depending on your use case, you might choose one or the other option and tailor it to your needs.

# %%
def query_db(params):
    matches = []
    # Querying the db
    result = query_graph(params)
    for r in result:
        product_id = r['p']['id']
        matches.append({
            "id": product_id,
            "name":r['p']['name']
        })
    return matches

# %%
def similarity_search(prompt, threshold=0.8):
    matches = []
    embedding = create_embedding(prompt)
    query = '''
            WITH $embedding AS inputEmbedding
            MATCH (p:Product)
            WHERE gds.similarity.cosine(inputEmbedding, p.embedding) > $threshold
            RETURN p
            '''
    result = graph.query(query, params={'embedding': embedding, 'threshold': threshold})
    for r in result:
        product_id = r['p']['id']
        matches.append({
            "id": product_id,
            "name":r['p']['name']
        })
    return matches

# %%
prompt_similarity = "I'm looking for nice curtains"
print(similarity_search(prompt_similarity))
# Out:
# []

# %% [markdown]
# Building a Langchain agent
#
# We will create a Langchain agent to handle conversations and probing the user for more context.
#
# We need to define exactly how the agent should behave, and give it access to our query and similarity search tools.

# %%
from langchain.agents import Tool, AgentExecutor, LLMSingleActionAgent, AgentOutputParser
from langchain.schema import AgentAction, AgentFinish, HumanMessage, SystemMessage


tools = [
    Tool(
        name="Query",
        func=query_db,
        description="Use this tool to find entities in the user prompt that can be used to generate queries"
    ),
    Tool(
        name="Similarity Search",
        func=similarity_search,
        description="Use this tool to perform a similarity search with the products in the database"
    )
]

tool_names = [f"{tool.name}: {tool.description}" for tool in tools]

# %%
from langchain_core.prompts.string import StringPromptTemplate
from typing import Callable


prompt_template = '''Your goal is to find a product in the database that best matches the user prompt.
You have access to these tools:

{tools}

Use the following format:

Question: the input prompt from the user
Thought: you should always think about what to do
Action: the action to take (refer to the rules below)
Action Input: the input to the action
Observation: the result of the action
... (this Thought/Action/Action Input/Observation can repeat N times)
Thought: I now know the final answer
Final Answer: the final answer to the original input question

Rules to follow:

1. Start by using the Query tool with the prompt as parameter. If you found results, stop here.
2. If the result is an empty array, use the similarity search tool with the full initial user prompt. If you found results, stop here.
3. If you cannot still cannot find the answer with this, probe the user to provide more context on the type of product they are looking for. 

Keep in mind that we can use entities of the following types to search for products:

{entity_types}.

3. Repeat Step 1 and 2. If you found results, stop here.

4. If you cannot find the final answer, say that you cannot help with the question.

Never return results if you did not find any results in the array returned by the query tool or the similarity search tool.

If you didn't find any result, reply: "Sorry, I didn't find any suitable products."

If you found results from the database, this is your final answer, reply to the user by announcing the number of results and returning results in this format (each new result should be on a new line):

name_of_the_product (id_of_the_product)"

Only use exact names and ids of the products returned as results when providing your final answer.


User prompt:
{input}

{agent_scratchpad}

'''

# Set up a prompt template
class CustomPromptTemplate(StringPromptTemplate):
    # The template to use
    template: str
        
    def format(self, **kwargs) -> str:
        # Get the intermediate steps (AgentAction, Observation tuples)
        # Format them in a particular way
        intermediate_steps = kwargs.pop("intermediate_steps")
        thoughts = ""
        for action, observation in intermediate_steps:
            thoughts += action.log
            thoughts += f"\nObservation: {observation}\nThought: "
        # Set the agent_scratchpad variable to that value
        kwargs["agent_scratchpad"] = thoughts
        ############## NEW ######################
        #tools = self.tools_getter(kwargs["input"])
        # Create a tools variable from the list of tools provided
        kwargs["tools"] = "\n".join(
            [f"{tool.name}: {tool.description}" for tool in tools]
        )
        # Create a list of tool names for the tools provided
        kwargs["tool_names"] = ", ".join([tool.name for tool in tools])
        kwargs["entity_types"] = json.dumps(entity_types)
        return self.template.format(**kwargs)


prompt = CustomPromptTemplate(
    template=prompt_template,
    tools=tools,
    input_variables=["input", "intermediate_steps"],
)

# %%
from typing import List, Union
import re

class CustomOutputParser(AgentOutputParser):
    
    def parse(self, llm_output: str) -> Union[AgentAction, AgentFinish]:
        
        # Check if agent should finish
        if "Final Answer:" in llm_output:
            return AgentFinish(
                # Return values is generally always a dictionary with a single `output` key
                # It is not recommended to try anything else at the moment :)
                return_values={"output": llm_output.split("Final Answer:")[-1].strip()},
                log=llm_output,
            )
        
        # Parse out the action and action input
        regex = r"Action: (.*?)[\n]*Action Input:[\s]*(.*)"
        match = re.search(regex, llm_output, re.DOTALL)
        
        # If it can't parse the output it raises an error
        # You can add your own logic here to handle errors in a different way i.e. pass to a human, give a canned response
        if not match:
            raise ValueError(f"Could not parse LLM output: `{llm_output}`")
        action = match.group(1).strip()
        action_input = match.group(2)
        
        # Return the action and action input
        return AgentAction(tool=action, tool_input=action_input.strip(" ").strip('"'), log=llm_output)
    
output_parser = CustomOutputParser()

# %%
from langchain import LLMChain
from langchain.agents.output_parsers.openai_tools import OpenAIToolsAgentOutputParser
from langchain.chat_models import ChatOllama

llm = ChatOllama(temperature=0, model="gpt-oss:20b-cloud")

# LLM chain consisting of the LLM and a prompt
llm_chain = LLMChain(llm=llm, prompt=prompt)

# Using tools, the LLM chain and output_parser to make an agent
tool_names = [tool.name for tool in tools]

agent = LLMSingleActionAgent(
    llm_chain=llm_chain, 
    output_parser=output_parser,
    stop=["\Observation:"], 
    allowed_tools=tool_names
)


agent_executor = AgentExecutor.from_agent_and_tools(agent=agent, tools=tools, verbose=True)
# Out:
# C:\Users\sushi\AppData\Local\Temp\ipykernel_20996\3125319258.py:15: LangChainDeprecationWarning: LangChain agents will continue to be supported, but it is recommended for new use cases to be built with LangGraph. LangGraph offers a more flexible and full-featured framework for building agents, including support for tool-calling, persistence of state, and human-in-the-loop workflows. For details, refer to the `LangGraph documentation <https://langchain-ai.github.io/langgraph/>`_ as well as guides for `Migrating from AgentExecutor <https://python.langchain.com/docs/how_to/migrate_agent/>`_ and LangGraph's `Pre-built ReAct agent <https://langchain-ai.github.io/langgraph/how-tos/create-react-agent/>`_.
#   agent = LLMSingleActionAgent(

# %%
def agent_interaction(user_prompt):
    agent_executor.run(user_prompt)

# %%
prompt1 = "I'm searching for pink shirts"
agent_interaction(prompt1)
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 2
#       1 prompt1 = "I'm searching for pink shirts"
# ----> 2 agent_interaction(prompt1)
#
# Cell In[122], line 2, in agent_interaction(user_prompt)
#       1 def agent_interaction(user_prompt):
# ----> 2     agent_executor.run(user_prompt)
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_core\_api\deprecation.py:193, in warning_emitting_wrapper(*args, **kwargs)
#     191 """Same as warning_emitting_wrapper, but for async functions."""
#     192 nonlocal warned
# --> 193 if not warned and not is_caller_internal():
#     194     warned = True
#     195     emit_warning()
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
#     631 if kwargs and not args:
#     632     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     633         _output_key
#     634     ]
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_core\_api\deprecation.py:193, in warning_emitting_wrapper(*args, **kwargs)
#     191 """Same as warning_emitting_wrapper, but for async functions."""
#     192 nonlocal warned
# --> 193 if not warned and not is_caller_internal():
#     194     warned = True
#     195     emit_warning()
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:410, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     378 """Execute the chain.
#     379
#     380 Args:
#    (...)    401         `Chain.output_keys`.
#     402 """
#     403 config = {
#     404     "callbacks": callbacks,
#     405     "tags": tags,
#     406     "metadata": metadata,
#     407     "run_name": run_name,
#     408 }
# --> 410 return self.invoke(
#     411     inputs,
#     412     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     413     return_only_outputs=return_only_outputs,
#     414     include_run_info=include_run_info,
#     415 )
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     162 try:
#     163     self._validate_inputs(inputs)
#     164     outputs = (
# --> 165         self._call(inputs, run_manager=run_manager)
#     166         if new_arg_supported
#     167         else self._call(inputs)
#     168     )
#     170     final_outputs: dict[str, Any] = self.prep_outputs(
#     171         inputs,
#     172         outputs,
#     173         return_only_outputs,
#     174     )
#     175 except BaseException as e:
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output,
#    1635             intermediate_steps,
#    1636             run_manager=run_manager,
#    1637         )
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:1325, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1316 def _take_next_step(
#    1317     self,
#    1318     name_to_tool_map: dict[str, BaseTool],
#    (...)   1322     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1323 ) -> Union[AgentFinish, list[tuple[AgentAction, str]]]:
#    1324     return self._consume_next_step(
# -> 1325         list(
#    1326             self._iter_next_step(
#    1327                 name_to_tool_map,
#    1328                 color_mapping,
#    1329                 inputs,
#    1330                 intermediate_steps,
#    1331                 run_manager,
#    1332             ),
#    1333         ),
#    1334     )
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:1352, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1349     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1351     # Call the LLM to see what to do.
# -> 1352     output = self._action_agent.plan(
#    1353         intermediate_steps,
#    1354         callbacks=run_manager.get_child() if run_manager else None,
#    1355         **inputs,
#    1356     )
#    1357 except OutputParserException as e:
#    1358     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:682, in LLMSingleActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     665 """Given input, decided what to do.
#     666
#     667 Args:
#    (...)    674     Action specifying what tool to use.
#     675 """
#     676 output = self.llm_chain.run(
#     677     intermediate_steps=intermediate_steps,
#     678     stop=self.stop,
#     679     callbacks=callbacks,
#     680     **kwargs,
#     681 )
# --> 682 return self.output_parser.parse(output)
#
# Cell In[119], line 24, in CustomOutputParser.parse(self, llm_output)
#      21 # If it can't parse the output it raises an error
#      22 # You can add your own logic here to handle errors in a different way i.e. pass to a human, give a canned response
#      23 if not match:
# ---> 24     raise ValueError(f"Could not parse LLM output: `{llm_output}`")
#      25 action = match.group(1).strip()
#      26 action_input = match.group(2)
#
# ValueError: Could not parse LLM output: ``

# %%
prompt2 = "Can you help me find a toys for my niece, she's 8"
agent_interaction(prompt2)
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 2
#       1 prompt2 = "Can you help me find a toys for my niece, she's 8"
# ----> 2 agent_interaction(prompt2)
#
# Cell In[122], line 2, in agent_interaction(user_prompt)
#       1 def agent_interaction(user_prompt):
# ----> 2     agent_executor.run(user_prompt)
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_core\_api\deprecation.py:193, in warning_emitting_wrapper(*args, **kwargs)
#     191 """Same as warning_emitting_wrapper, but for async functions."""
#     192 nonlocal warned
# --> 193 if not warned and not is_caller_internal():
#     194     warned = True
#     195     emit_warning()
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
#     631 if kwargs and not args:
#     632     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     633         _output_key
#     634     ]
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain_core\_api\deprecation.py:193, in warning_emitting_wrapper(*args, **kwargs)
#     191 """Same as warning_emitting_wrapper, but for async functions."""
#     192 nonlocal warned
# --> 193 if not warned and not is_caller_internal():
#     194     warned = True
#     195     emit_warning()
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:410, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     378 """Execute the chain.
#     379
#     380 Args:
#    (...)    401         `Chain.output_keys`.
#     402 """
#     403 config = {
#     404     "callbacks": callbacks,
#     405     "tags": tags,
#     406     "metadata": metadata,
#     407     "run_name": run_name,
#     408 }
# --> 410 return self.invoke(
#     411     inputs,
#     412     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     413     return_only_outputs=return_only_outputs,
#     414     include_run_info=include_run_info,
#     415 )
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\chains\base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     162 try:
#     163     self._validate_inputs(inputs)
#     164     outputs = (
# --> 165         self._call(inputs, run_manager=run_manager)
#     166         if new_arg_supported
#     167         else self._call(inputs)
#     168     )
#     170     final_outputs: dict[str, Any] = self.prep_outputs(
#     171         inputs,
#     172         outputs,
#     173         return_only_outputs,
#     174     )
#     175 except BaseException as e:
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output,
#    1635             intermediate_steps,
#    1636             run_manager=run_manager,
#    1637         )
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:1325, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1316 def _take_next_step(
#    1317     self,
#    1318     name_to_tool_map: dict[str, BaseTool],
#    (...)   1322     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1323 ) -> Union[AgentFinish, list[tuple[AgentAction, str]]]:
#    1324     return self._consume_next_step(
# -> 1325         list(
#    1326             self._iter_next_step(
#    1327                 name_to_tool_map,
#    1328                 color_mapping,
#    1329                 inputs,
#    1330                 intermediate_steps,
#    1331                 run_manager,
#    1332             ),
#    1333         ),
#    1334     )
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:1352, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1349     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1351     # Call the LLM to see what to do.
# -> 1352     output = self._action_agent.plan(
#    1353         intermediate_steps,
#    1354         callbacks=run_manager.get_child() if run_manager else None,
#    1355         **inputs,
#    1356     )
#    1357 except OutputParserException as e:
#    1358     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\Users\sushi\anaconda3\envs\llms\Lib\site-packages\langchain\agents\agent.py:682, in LLMSingleActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     665 """Given input, decided what to do.
#     666
#     667 Args:
#    (...)    674     Action specifying what tool to use.
#     675 """
#     676 output = self.llm_chain.run(
#     677     intermediate_steps=intermediate_steps,
#     678     stop=self.stop,
#     679     callbacks=callbacks,
#     680     **kwargs,
#     681 )
# --> 682 return self.output_parser.parse(output)
#
# Cell In[119], line 24, in CustomOutputParser.parse(self, llm_output)
#      21 # If it can't parse the output it raises an error
#      22 # You can add your own logic here to handle errors in a different way i.e. pass to a human, give a canned response
#      23 if not match:
# ---> 24     raise ValueError(f"Could not parse LLM output: `{llm_output}`")
#      25 action = match.group(1).strip()
#      26 action_input = match.group(2)
#
# ValueError: Could not parse LLM output: ``

# %% [markdown]
# Building a code-only experience
#
# As our experiments show, using an agent for this type of task might not be the best option.
#
# Indeed, the agent seems to retrieve results from the tools, but comes up with made-up responses.
#
# For this specific use case, if the conversational aspect is less relevant, we can actually create a function that will call our previously-defined tasks and provide an answer.

# %%
import logging

def answer(prompt, similar_items_limit=10):
    print(f'Prompt: "{prompt}"\n')
    params = define_query(prompt)
    print(params)
    result = query_db(params)
    print(f"Found {len(result)} matches with Query function.\n")
    if len(result) == 0:
        result = similarity_search(prompt)
        print(f"Found {len(result)} matches with Similarity search function.\n")
        if len(result) == 0:
            return "I'm sorry, I did not find a match. Please try again with a little bit more details."
    print(f"I have found {len(result)} matching items:\n")
    similar_items = []
    for r in result:
        similar_items.extend(query_similar_items(r['id']))
        print(f"{r['name']} ({r['id']})")
    print("\n")
    if len(similar_items) > 0:
        print("Similar items that might interest you:\n")
        for i in similar_items[:similar_items_limit]:
            print(f"{i['name']} ({i['id']})")
    print("\n\n\n")
    return result

# %%
prompt1 = "I'm looking for food items to gift to someone for Christmas. Ideally chocolate."
answer(prompt1)

prompt2 = "Help me find women clothes for my wife. She likes blue."
answer(prompt2)

prompt3 = "I'm looking for nice things to decorate my living room."
answer(prompt3)

prompt4 = "Can you help me find a gift for my niece? She's 8 and she likes pink."
answer(prompt4)
# Out:
# Prompt: "I'm looking for food items to gift to someone for Christmas. Ideally chocolate."
#
# {
#   "product": "chocolate",
#   "category": "food"
# }
# Found 1 matches with Query function.
#
# I have found 1 matching items:
#
# Chocolate Treats (535662)
#
#
#
#
#
#
# Prompt: "Help me find women clothes for my wife. She likes blue."
#
# {
#   "color": "blue",
#   "category": "women clothing",
#   "age_group": "adults"
# }
# Found 1 matches with Query function.
#
# I have found 1 matching items:
#
# Womens Shift Knee-Long Dress (1483279)
#
#
# Similar items that might interest you:
#
# Womens Cotton Ankle Length Leggings (1594019)
# A Line Open Back Satin Prom Dress (1955999)
# Turtleneck Oversized Sweaters (2535064)
# Plain V Neck Half Sleeves T Shirt (1519827)
# Womens Satin Semi-Stitched Lehenga Choli (2763742)
# Womens Drawstring Harem Pants (1233616)
# Underwire Bra (1325580)
# Chiffon printed dupatta (2919319)
# Womens Lightly Padded Non-Wired Printed T-Shirt Bra (1954205)
# Glossies Thong (941830)
#
#
#
#
# Prompt: "I'm looking for nice things to decorate my living room."
#
# {
#     "category": "home decoration"
# }
# Found 27 matches with Query function.
#
# I have found 27 matching items:
#
# Blackout Curtain (1925202)
# Metal Bucket Shape Plant Pot (2152929)
# Kitchen Backsplash Wallpaper (2026580)
# Fan Embossed Planter (1810976)
# Star Trek 50th Anniversary Ceramic Storage Jar (1262926)
# Hand Painted and Handmade Hanging Wind Chimes (2075497)
# 100% Blackout Curtains (1706369)
# The Wall Poster (2749965)
# Wall Hanging Plates (1662896)
# Embroidered Leaf Pattern Semi Sheer Curtains (1922352)
# Printed Landscape Photo Frame Style Decal Decor (1730566)
# Vintage Artificial Peony Bouquet (1725917)
# Rainbow Color Cup LED Flashing Light (2588967)
# Indoor Doormat (2150415)
# African Art Print (1289910)
# Artificial Pothos Floor Plant (1549539)
# Single Toggle Switch (937070)
# Wood Picture Frame (1180921)
# Framed Poster of Vastu Seven Running Horse (1782219)
# Cabin, Reindeer and Snowy Forest Trees Wall Art Prints (2552742)
# Moon Resting 4 by Amy Vangsgard (1278281)
# Unicorn Curtains (2243426)
# Owl Macrame Wall Hanging (2088100)
# Floral Wall Art (1789190)
# Kitchen Still Life Canvas Wall Art (2013780)
# Fall Pillow Covers (2403589)
# Kathakali Cloth and Paper Mache Handpainted Dancer Male Doll (1686699)
#
#
# Similar items that might interest you:
#
# Metal Bucket Shape Plant Pot (2152929)
# Kitchen Backsplash Wallpaper (2026580)
# Star Trek 50th Anniversary Ceramic Storage Jar (1262926)
# Hand Painted and Handmade Hanging Wind Chimes (2075497)
# 100% Blackout Curtains (1706369)
# The Wall Poster (2749965)
# Wall Hanging Plates (1662896)
# Embroidered Leaf Pattern Semi Sheer Curtains (1922352)
# Printed Landscape Photo Frame Style Decal Decor (1730566)
# Vintage Artificial Peony Bouquet (1725917)
#
#
#
#
# Prompt: "Can you help me find a gift for my niece? She's 8 and she likes pink."
#
# {
#     "color": "pink",
#     "age_group": "children"
# }
# Found 2 matches with Query function.
#
# I have found 2 matching items:
#
# Suitcase Music Box (2516354)
# Unicorn Curtains (2243426)
# [{'id': 2516354, 'name': 'Suitcase Music Box'},
#  {'id': 2243426, 'name': 'Unicorn Curtains'}]

# %% [markdown]
# Conclusion
#
# User experience
#
# When the primary objective is to extract specific information from our database, Large Language Models (LLMs) can significantly enhance our querying capabilities.
#
# However, it's crucial to base much of this process on robust code logic to ensure a foolproof user experience.
#
# For crafting a genuinely conversational chatbot, further exploration in prompt engineering is necessary, possibly incorporating few-shot examples. This approach helps mitigate the risk of generating inaccurate or misleading information and ensures more precise responses.
#
# Ultimately, the design choice depends on the desired user experience. For instance, if the aim is to create a visual recommendation system, the importance of a conversational interface is less relevant.
#
# Working with a knowledge graph
#
# Retrieving content from a knowledge graph adds complexity but can be useful if you want to leverage connections between items.
#
# The querying part of this notebook would work on a relational database as well, the knowledge graph comes in handy when we want to couple the results with similar items that the graph is surfacing.
#
# Considering the added complexity, make sure using a knowledge graph is the best option for your use case. If it is the case, feel free to refine what this cookbook presents to match your needs and perform even better!
